# %% [markdown]
# # Normalizacja metadanych produktów (LLM)
#
# **Etap 1** — LLM analizuje wszystkie unikalne wartości z każdej kolumny i tworzy canonical mapping
# **Etap 2** — LLM mapuje wartości każdego wiersza na canonical (używając listy z etapu 1)
# **Output** → `zurada_products_with_metadata_cleaned.csv`
#
# Checkpoint po etapie 2 — wznawialne.

# %%
# %pip install openai pandas tqdm --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, json, time
import pandas as pd
from collections import Counter
from tqdm.notebook import tqdm
from openai import OpenAI

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY", "Brak klucza API")  # ustaw zmienną środowiskową lub wklej tu
MODEL          = "gpt-5.5"
INPUT_CSV      = "zurada_products_with_metadata.csv"
CANONICAL_JSON = "zurada_canonical_mappings.json"   # wynik etapu 1
CHECKPOINT_CSV = "zurada_normalize_checkpoint.csv"  # wynik etapu 2
OUTPUT_CSV     = "zurada_products_with_metadata_cleaned.csv"
SLEEP_BETWEEN  = 0.3
MAX_RETRIES    = 3

LIST_COLS   = ["dozwolone_powierzchnie", "odradzane_powierzchnie",
               "metoda_mycia", "zgodnosc_i_certyfikaty", "ostrzezenia_bhp"]
STRING_COLS = ["odczyn_ph"]  # te mają prostą wartość, nie listę
ALL_COLS    = LIST_COLS + STRING_COLS

client = OpenAI(api_key=OPENAI_API_KEY)
print(f"Model: {MODEL}")
# Out:
# Model: gpt-5.5

# %%
df = pd.read_csv(INPUT_CSV)
print(f"Wczytano {len(df)} produktów")


def parse_val(val, is_list=True):
    """Parsuje wartość z CSV (JSON string lub plain string)."""
    if pd.isna(val) or str(val).strip() == "":
        return [] if is_list else ""
    try:
        parsed = json.loads(val)
        return parsed if is_list else str(parsed)
    except Exception:
        return [str(val)] if is_list else str(val)


def collect_unique(col, is_list=True):
    """Zbiera wszystkie unikalne wartości z kolumny."""
    counter = Counter()
    for raw in df[col].dropna():
        items = parse_val(raw, is_list)
        if is_list:
            counter.update(items)
        else:
            counter[items] += 1
    return counter


print("Funkcje pomocnicze gotowe.")
# Out:
# Wczytano 100 produktów
# Funkcje pomocnicze gotowe.

# %% [markdown]
# ## Etap 1 — Generowanie canonical mappings przez LLM

# %%
def generate_canonical_mapping(col_name, unique_counter):
    items = list(unique_counter.keys())
    freq_lines = "\n".join(f"{unique_counter[v]:3d}x  {v}" for v in items)

    col_context = {
        "dozwolone_powierzchnie":  "powierzchnie/materiały, na których produkt MOŻE być stosowany",
        "odradzane_powierzchnie":  "powierzchnie/materiały, na których produkt NIE POWINIEN być stosowany",
        "metoda_mycia":            "metody aplikacji/mycia (ręczne, maszynowe, ciśnieniowe itp.)",
        "zgodnosc_i_certyfikaty":  "certyfikaty, normy i zgodności produktu",
        "ostrzezenia_bhp":         "ostrzeżenia i instrukcje bezpieczeństwa",
        "odczyn_ph":               "odczyn pH produktu",
    }.get(col_name, col_name)

    user_msg = (
        f"Kolumna: {col_name} ({col_context})\n"
        f"Lista {len(items)} unikalnych wartości (z częstotliwością):\n"
        f"{freq_lines}\n\n"
        'Zwróć JSON: {"canonical_values": [...], "mapping": {"oryg": "canonical", ...}}'
    )

    for attempt in range(1, MAX_RETRIES + 1):
        print(f"    [attempt {attempt}] wysyłam {len(items)} wartości do modelu...")
        try:
            response = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": PHASE1_SYSTEM},
                    {"role": "user",   "content": user_msg},
                ],
                response_format={"type": "json_object"},
                max_completion_tokens=6000,
            )
            content = response.choices[0].message.content
            if not content:
                refusal = getattr(response.choices[0].message, "refusal", None)
                raise ValueError(f"Pusta odpowiedź. Refusal: {refusal}")
            parsed = json.loads(content)
            canonical = parsed.get("canonical_values", [])
            mapping   = parsed.get("mapping", {})
            print(f"    OK — {len(canonical)} canonical values, {len(mapping)}/{len(items)} mappings")
            return {"canonical_values": canonical, "mapping": mapping}
        except Exception as e:
            wait = 2 ** attempt
            print(f"    [RETRY {attempt}/{MAX_RETRIES}] {col_name} — {e} — czekam {wait}s")
            time.sleep(wait)

    raise RuntimeError(f"Nie udało się wygenerować mappingu dla {col_name}")


print("Funkcja generate_canonical_mapping gotowa.")
# Out:
# Funkcja generate_canonical_mapping gotowa.

# %%
def generate_canonical_mapping(col_name, unique_counter):
    items = list(unique_counter.keys())
    freq_lines = "\n".join(f"{unique_counter[v]:3d}x  {v}" for v in items)

    col_context = {
        "dozwolone_powierzchnie":  "powierzchnie/materiały, na których produkt MOŻE być stosowany",
        "odradzane_powierzchnie":  "powierzchnie/materiały, na których produkt NIE POWINIEN być stosowany",
        "metoda_mycia":            "metody aplikacji/mycia (ręczne, maszynowe, ciśnieniowe itp.)",
        "zgodnosc_i_certyfikaty":  "certyfikaty, normy i zgodności produktu",
        "ostrzezenia_bhp":         "ostrzeżenia i instrukcje bezpieczeństwa",
        "odczyn_ph":               "odczyn pH produktu",
    }.get(col_name, col_name)

    user_msg = (
        f"Kolumna: {col_name} ({col_context})\n"
        f"Lista {len(items)} unikalnych wartości (z częstotliwością):\n"
        f"{freq_lines}\n\n"
        'Zwróć JSON: {"canonical_values": [...], "mapping": {"oryg": "canonical", ...}}'
    )

    for attempt in range(1, MAX_RETRIES + 1):
        print(f"    [attempt {attempt}] wysyłam {len(items)} wartości do modelu...")
        try:
            response = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": PHASE1_SYSTEM},
                    {"role": "user",   "content": user_msg},
                ],
                response_format={"type": "json_object"},
                max_completion_tokens=60000,
            )
            content = response.choices[0].message.content
            if not content:
                refusal = getattr(response.choices[0].message, "refusal", None)
                raise ValueError(f"Pusta odpowiedź. Refusal: {refusal}")
            parsed = json.loads(content)
            canonical = parsed.get("canonical_values", [])
            mapping   = parsed.get("mapping", {})
            print(f"    OK — {len(canonical)} canonical values, {len(mapping)}/{len(items)} mappings")
            return {"canonical_values": canonical, "mapping": mapping}
        except Exception as e:
            wait = 2 ** attempt
            print(f"    [RETRY {attempt}/{MAX_RETRIES}] {col_name} — {e} — czekam {wait}s")
            time.sleep(wait)

    raise RuntimeError(f"Nie udało się wygenerować mappingu dla {col_name}")


print("Funkcja generate_canonical_mapping gotowa.")
# Out:
# Funkcja generate_canonical_mapping gotowa.

# %%
# Wczytaj checkpoint jeśli istnieje
if os.path.exists(CANONICAL_JSON):
    with open(CANONICAL_JSON, "r", encoding="utf-8") as f:
        all_mappings = json.load(f)
    print(f"Wczytano istniejące mappingi: {list(all_mappings.keys())}")
else:
    all_mappings = {}
    print("Brak mappingów — generuję od zera.")

for col in ALL_COLS:
    if col in all_mappings:
        print(f"  Pomijam {col} (już wygenerowane)")
        continue

    is_list = col in LIST_COLS
    counter = collect_unique(col, is_list=is_list)
    print(f"  Generuję mapping dla '{col}' ({len(counter)} unikalnych wartości)...")

    result = generate_canonical_mapping(col, counter)
    all_mappings[col] = result

    # Zapis po każdej kolumnie
    with open(CANONICAL_JSON, "w", encoding="utf-8") as f:
        json.dump(all_mappings, f, ensure_ascii=False, indent=2)

    print(f"    → {len(result['canonical_values'])} canonical values, {len(result['mapping'])} mappings")
    time.sleep(SLEEP_BETWEEN)

print("\nEtap 1 zakończony. Mappingi zapisane w:", CANONICAL_JSON)
# Out:
# Brak mappingów — generuję od zera.
#   Generuję mapping dla 'dozwolone_powierzchnie' (330 unikalnych wartości)...
#     [attempt 1] wysyłam 330 wartości do modelu...
#     OK — 202 canonical values, 330/330 mappings
#     → 202 canonical values, 330 mappings
#   Generuję mapping dla 'odradzane_powierzchnie' (74 unikalnych wartości)...
#     [attempt 1] wysyłam 74 wartości do modelu...
#     OK — 48 canonical values, 74/74 mappings
#     → 48 canonical values, 74 mappings
#   Generuję mapping dla 'metoda_mycia' (56 unikalnych wartości)...
#     [attempt 1] wysyłam 56 wartości do modelu...
#     OK — 23 canonical values, 56/56 mappings
#     → 23 canonical values, 56 mappings
#   Generuję mapping dla 'zgodnosc_i_certyfikaty' (30 unikalnych wartości)...
#     [attempt 1] wysyłam 30 wartości do modelu...
#     OK — 20 canonical values, 30/30 mappings
#     → 20 canonical values, 30 mappings
#   Generuję mapping dla 'ostrzezenia_bhp' (134 unikalnych wartości)...
#     [attempt 1] wysyłam 134 wartości do modelu...
#     OK — 63 canonical values, 134/134 mappings
#     → 63 canonical values, 134 mappings
#   Generuję mapping dla 'odczyn_ph' (16 unikalnych wartości)...
#     [attempt 1] wysyłam 16 wartości do modelu...
#     OK — 5 canonical values, 16/16 mappings
#     → 5 canonical values, 16 mappings
#
# Etap 1 zakończony. Mappingi zapisane w: zurada_canonical_mappings.json

# %%
# Podgląd wygenerowanych canonical values
for col, data in all_mappings.items():
    print(f"\n=== {col} ({len(data['canonical_values'])} canonical) ===")
    for v in sorted(data["canonical_values"]):
        print(f"  • {v}")
# Out:
# === dozwolone_powierzchnie (202 canonical) ===
#   • PVC
#   • akcesoria kuchenne
#   • aluminium
#   • armatura
#   • balustrady
#   • bemary
#   • beton
#   • bez kontaktu z żywnością
#   • blachy
#   • blaty
#   • bojlery
#   • brodziki
#   • centra logistyczne
#   • ceramika
#   • ciepłe powierzchnie
#   • ciągi technologiczne
#   • ciężarówki
#   • cysterny
#   • czajnik elektryczny
#   • czajnik tradycyjny
#   • czyste elementy
#   • części samochodowe
#   • drewno
#   • drewno lakierowane
#   • dywaniki
#   • dywany
#   • ekspresy do kawy
#   • elementy pionowe
#   • epoksyd
#   • fasady
#   • felgi
#   • fermentatory
#   • fronty szafek
#   • fugi
#   • garaże
#   • garnki
#   • glazura
#   • gofrownice
#   • granit
#   • gres
#   • grille
#   • guma
#   • gładkie powierzchnie
#   • homogenizatory
#   • instalacje
#   • kabiny prysznicowe
#   • kamień
#   • kamień naturalny
#   • kamień sztuczny
#   • karoseria
#   • kauczuk
#   • klamki
#   • klatki schodowe
#   • klinkier
#   • kokpit
#   • kominki
#   • komórki
#   • kontakt z żywnością
#   • kostka brukowa
#   • kotły
#   • kratki kanalizacyjne
#   • ksylolit
#   • kuchenki
#   • lakier
#   • laminat
#   • lampy
#   • lastryko
#   • linie technologiczne
#   • linoleum
#   • lodówki
#   • marmur
#   • maszyny
#   • maszyny budowlane
#   • maszyny rolnicze
#   • meble
#   • meble tapicerowane
#   • metal
#   • mieszalniki
#   • naczynia
#   • naczynia aluminiowe
#   • naczynia emaliowane
#   • naczynia stalowe
#   • nagrzewnice
#   • naleśnikarki
#   • narzędzia
#   • odporne na alkalia
#   • odporne na kwasy
#   • odporne na wodę
#   • odporne na wybielacze
#   • odpływy
#   • odzież robocza
#   • okapy
#   • opiekacze
#   • opony
#   • panele
#   • parapety
#   • parkiety
#   • parkingi
#   • parowniki
#   • patelnie
#   • piece
#   • piekarniki
#   • pisuary
#   • piwnice
#   • plandeki
#   • podjazdy
#   • podłogi
#   • podłogi
#   • podłogi zabrudzone
#   • podłogi żywiczne
#   • pojazdy
#   • pojemniki plastikowe
#   • pojemniki szklane
#   • polerowane aluminium
#   • porcelana
#   • porowate powierzchnie
#   • poręcze
#   • posadzki przemysłowe
#   • posadzki twarde
#   • powierzchnie błyszczące
#   • powierzchnie kuchenne
#   • powierzchnie materiałowe
#   • powierzchnie matowe
#   • powierzchnie mineralne
#   • powierzchnie obiektowe
#   • powierzchnie pionowe
#   • powierzchnie ponadpodłogowe
#   • powierzchnie sanitarne
#   • powierzchnie szkliste
#   • powierzchnie szkliwione
#   • powierzchnie wielkometrażowe
#   • powierzchnie zewnętrzne
#   • powłoki ochronne
#   • pralki
#   • przedmioty
#   • przemysł farmaceutyczny
#   • płytki
#   • płytki ceramiczne
#   • płytki kwasoodporne
#   • reflektory
#   • rurociągi
#   • rury
#   • samochody
#   • schody
#   • siedzenia
#   • silniki
#   • skóra
#   • skóra dłoni
#   • sprzęt kuchenny
#   • sprzęt pomocniczy
#   • stal
#   • stal kwasoodporna
#   • stal nierdzewna
#   • stal stopowa
#   • stoły
#   • sufity
#   • syfony
#   • szkło
#   • sztućce
#   • szyby kominkowe
#   • talerze
#   • tapicerka meblowa
#   • tapicerka samochodowa
#   • tapicerka tekstylna
#   • tekstylia
#   • terakota
#   • tkaniny
#   • toalety
#   • tostery
#   • twarde powierzchnie
#   • tworzywa sztuczne
#   • umywalki
#   • urządzenia
#   • urządzenia biurowe
#   • urządzenia do kebabów
#   • urządzenia gastronomiczne
#   • urządzenia kuchenne
#   • uszczelki
#   • wanny
#   • wewnętrzne powierzchnie pojazdów
#   • windy
#   • winyl
#   • witryny chłodnicze
#   • wnętrze samochodu
#   • woski
#   • wrażliwe na alkalia
#   • wszystkie powierzchnie
#   • wykładziny
#   • wykładziny PVC
#   • wymienniki
#   • wyparzarki
#   • wyposażenie wnętrz
#   • wózki widłowe
#   • zabezpieczone drewno
#   • zatłuszczone powierzchnie
#   • zbiorniki
#   • zewnętrzne powierzchnie pojazdów
#   • zlewozmywaki
#   • zmywalne powierzchnie
#   • zmywarki
#   • łazienki
#   • ściany
#
# === odradzane_powierzchnie (48 canonical) ===
#   • aluminium
#   • armatura łazienkowa
#   • bazalt
#   • beton
#   • brąz
#   • bębny
#   • błony śluzowe
#   • drewno
#   • fugi o nietrwałym kolorze
#   • granit
#   • kamień wapienny
#   • korek
#   • linoleum
#   • marmur
#   • miedź
#   • mosiądz
#   • nasłonecznione powierzchnie
#   • nielakierowane drewno
#   • niezaimpregnowane drewno
#   • otwarte rany
#   • panele
#   • parkiet
#   • piekarniki z automatycznym myciem
#   • powierzchnie chłonne
#   • powierzchnie lakierowane
#   • powierzchnie malowane
#   • powierzchnie ocynkowane
#   • powierzchnie wrażliwe na alkohol
#   • powierzchnie wrażliwe na chlor
#   • powierzchnie wrażliwe na kwasy
#   • powierzchnie wrażliwe na odtłuszczacze
#   • powierzchnie wrażliwe na wodę
#   • powierzchnie wrażliwe na wybielacze
#   • powierzchnie wrażliwe na zasady
#   • powierzchnie zabezpieczone polimerem
#   • rozgrzana karoseria
#   • rozgrzane powierzchnie
#   • rozgrzany lakier
#   • stal
#   • szkło akrylowe
#   • szyba czołowa
#   • tapicerka skórzana
#   • tarcze hamulcowe
#   • trawertyn
#   • zaciski
#   • zmywarki domowe
#   • łupki
#   • żeliwo
#
# === metoda_mycia (23 canonical) ===
#   • CIP
#   • aplikacja gąbką
#   • aplikacja rękawicą
#   • aplikator
#   • automatyczne
#   • ciśnieniowe
#   • czyszczenie
#   • maszynowe
#   • mopowanie
#   • myjnie samochodowe
#   • natryskowe
#   • pianowe
#   • pranie
#   • przecieranie ściereczką
#   • ręczne
#   • spłukiwanie
#   • systemy dozujące
#   • szorowanie
#   • ultradźwiękowe
#   • wcieranie w dłonie
#   • wybielanie
#   • zanurzeniowe
#   • zmywarki
#
# === zgodnosc_i_certyfikaty (20 canonical) ===
#   • HACCP
#   • IFRA
#   • PN-EN 13036-4
#   • PN-EN 1500:2013
#   • RSPO
#   • bez EDTA
#   • bez EDTA/NTA/SLS/fosforanów/dodecylobenzenosulfonianów
#   • bez NTA
#   • bez SLS
#   • bez dodecylobenzenosulfonianów
#   • bez fosforanów
#   • biodegradowalny
#   • do przemysłu spożywczego
#   • ekologiczny
#   • europejskie normy mikrobiologiczne
#   • nie powoduje eutrofizacji
#   • opakowanie do ponownego napełnienia
#   • opakowanie do recyklingu
#   • przebadany dermatologicznie
#   • składniki roślinne
#
# === ostrzezenia_bhp (63 canonical) ===
#   • aplikować na ciepło
#   • aplikować na lakier
#   • aplikować piankę i spłukać
#   • dezynfekcja rąk według producenta
#   • dobrać dawkę zmywarki
#   • dobrać stężenie
#   • instrukcja urządzenia
#   • karta charakterystyki
#   • karta i zalecenia producenta
#   • karta i zasady bezpieczeństwa
#   • karta stanowiskowa
#   • nie do pieców parowych
#   • nie do zmywarek domowych
#   • nie dopuścić do wyschnięcia
#   • oczyścić uszczelki
#   • okulary i rękawice
#   • okulary ochronne
#   • podstawowe zasady bezpieczeństwa
#   • przechowywać 5–25°C
#   • przepłukać spryskiwacz
#   • recykling opakowania
#   • rozcieńczyć według dozowania
#   • rozcieńczyć według zabrudzenia
#   • rękawice ochronne
#   • sprawdzić trwałość kolorów
#   • spłukać czystą wodą
#   • spłukać i osuszyć
#   • spłukać naczynia wodą pitną
#   • spłukać po 15 minutach
#   • spłukać po działaniu
#   • spłukać pod ciśnieniem
#   • spłukać ręce
#   • spłukać wodą pitną
#   • stosowanie okresowe
#   • stosować zgodnie z przeznaczeniem
#   • temperatura powierzchni 30–70°C
#   • temperatura wody 20–30°C
#   • umyć ręce
#   • unikać alkoholu
#   • unikać aluminium i wybielania
#   • unikać chloru
#   • unikać drewna i wody
#   • unikać gorąca i słońca
#   • unikać kontaktu z oczami
#   • unikać kwasów
#   • unikać kwasów i metali
#   • unikać ran i śluzówek
#   • unikać rozgrzanego lakieru
#   • unikać szyby czołowej
#   • unikać wody
#   • unikać wody alkoholu polimeru
#   • unikać zasad
#   • unikać żeliwa
#   • użytek profesjonalny
#   • użytek zewnętrzny
#   • wykonać próbę wstępną
#   • wytrzeć szkło do sucha
#   • zabezpieczyć elektrykę
#   • zalecane dozowanie
#   • zalecenia producenta
#   • zalecenia producenta zmywarki
#   • zimny silnik
#   • środki ochrony osobistej
#
# === odczyn_ph (5 canonical) ===
#   • kwaśny
#   • lekko zasadowy
#   • neutralny
#   • silnie zasadowy
#   • zasadowy

# %% [markdown]
# ## Etap 2 — Mapowanie każdego wiersza przez LLM

# %%
def build_phase2_schema(col, is_list):
    canonical_vals = all_mappings[col]["canonical_values"]
    enum_values = canonical_vals + [""]  # pusty string dla brak wartości

    if is_list:
        return {
            "type": "object",
            "properties": {
                "values": {
                    "type": "array",
                    "items": {"type": "string", "enum": enum_values},
                    "description": f"Zmapowane wartości kolumny {col} na canonical. Puste [] jeśli brak."
                }
            },
            "required": ["values"],
            "additionalProperties": False
        }
    else:
        return {
            "type": "object",
            "properties": {
                "value": {
                    "type": "string",
                    "enum": enum_values,
                    "description": f"Zmapowana wartość kolumny {col} na canonical. Pusty string jeśli brak."
                }
            },
            "required": ["value"],
            "additionalProperties": False
        }


PHASE2_SYSTEM = """Jesteś asystentem normalizacji danych.
Dostajesz listę surowych wartości z jednej kolumny produktu i listę dozwolonych canonical values.
Zmapuj każdą surową wartość na najbliższy canonical odpowiednik.
Jeśli wartość nie pasuje do żadnej canonical — usuń ją (nie zwracaj jej).
Nie dodawaj wartości spoza canonical_values.
Odpowiadasz wyłącznie poprawnym JSON."""


def map_row_column(raw_val, col, is_list):
    """Mapuje wartości jednej kolumny jednego wiersza na canonical."""
    parsed = parse_val(raw_val, is_list)

    # Szybka ścieżka: jeśli puste — zwróć puste
    if not parsed or parsed == []:
        return [] if is_list else ""

    canonical_vals = all_mappings[col]["canonical_values"]
    mapping = all_mappings[col]["mapping"]

    # Szybka ścieżka: spróbuj programistycznego mappingu najpierw
    if is_list:
        result = []
        needs_llm = []
        for v in parsed:
            if v in mapping and mapping[v] in canonical_vals:
                result.append(mapping[v])
            else:
                needs_llm.append(v)
    else:
        if parsed in mapping and mapping[parsed] in canonical_vals:
            return mapping[parsed]
        needs_llm = [parsed]
        result = []

    # Jeśli wszystko zmapowane programistycznie — nie wywołuj LLM
    if not needs_llm:
        return list(dict.fromkeys(result)) if is_list else (result[0] if result else "")

    # Wywołaj LLM dla wartości bez mappingu
    schema = build_phase2_schema(col, is_list)
    canonical_str = ", ".join(f'"{v}"' for v in canonical_vals)
    raw_str = json.dumps(needs_llm if is_list else needs_llm[0], ensure_ascii=False)

    user_msg = f"""Kolumna: {col}
Dozwolone canonical values: [{canonical_str}]

Surowe wartości do zmapowania: {raw_str}

Zmapuj na canonical. Usuń to, co nie pasuje."""

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": PHASE2_SYSTEM},
                    {"role": "user",   "content": user_msg},
                ],
                response_format={
                    "type": "json_schema",
                    "json_schema": {
                        "name": "row_mapping",
                        "strict": True,
                        "schema": schema,
                    }
                },
                max_completion_tokens=500,
            )
            llm_result = json.loads(response.choices[0].message.content)
            if is_list:
                llm_vals = [v for v in llm_result.get("values", []) if v and v in canonical_vals]
                combined = result + llm_vals
                return list(dict.fromkeys(combined))  # dedup zachowując kolejność
            else:
                v = llm_result.get("value", "")
                return v if v in canonical_vals else ""
        except Exception as e:
            wait = 2 ** attempt
            print(f"    [RETRY {attempt}] col={col} — {e} — czekam {wait}s")
            time.sleep(wait)

    # Fallback: zwróć tylko programistycznie zmapowane
    return list(dict.fromkeys(result)) if is_list else (result[0] if result else "")


print("Funkcja map_row_column gotowa (hybrydowa: mapping dict + LLM dla reszty).")
# Out:
# Funkcja map_row_column gotowa (hybrydowa: mapping dict + LLM dla reszty).

# %%
# ── Główna pętla etapu 2 ─────────────────────────────────────────────────────
if os.path.exists(CHECKPOINT_CSV):
    done_df  = pd.read_csv(CHECKPOINT_CSV)
    done_ids = set(done_df["product_id"].astype(int).tolist())
    print(f"Checkpoint: {len(done_ids)} produktów już przetworzonych.")
else:
    done_df  = pd.DataFrame()
    done_ids = set()
    print("Brak checkpointu — zaczynam od początku.")

to_process = df[~df["product_id"].astype(int).isin(done_ids)]
print(f"Do przetworzenia: {len(to_process)} produktów.")

results = []

for _, row in tqdm(to_process.iterrows(), total=len(to_process), desc="Normalizacja wierszy"):
    record = {"product_id": int(row["product_id"])}

    for col in LIST_COLS:
        mapped = map_row_column(row.get(col), col, is_list=True)
        record[col] = json.dumps(mapped, ensure_ascii=False)

    for col in STRING_COLS:
        mapped = map_row_column(row.get(col), col, is_list=False)
        record[col] = mapped

    results.append(record)
    time.sleep(SLEEP_BETWEEN)

    if len(results) % 5 == 0:
        batch = pd.DataFrame(results)
        combined = pd.concat([done_df, batch], ignore_index=True) if not done_df.empty else batch
        combined.to_csv(CHECKPOINT_CSV, index=False)

if results:
    batch = pd.DataFrame(results)
    done_df = pd.concat([done_df, batch], ignore_index=True) if not done_df.empty else batch
    done_df.to_csv(CHECKPOINT_CSV, index=False)

print(f"\nEtap 2 zakończony. {len(done_df)} produktów w checkpoincie.")
# Out:
# Brak checkpointu — zaczynam od początku.
# Do przetworzenia: 100 produktów.
# Normalizacja wierszy:   0%|          | 0/100 [00:00<?, ?it/s]
# Etap 2 zakończony. 100 produktów w checkpoincie.

# %%
# ── Scalenie z oryginalnym CSV i zapis ───────────────────────────────────────
clean_meta = pd.read_csv(CHECKPOINT_CSV)
clean_meta["product_id"] = clean_meta["product_id"].astype(int)

# Zacznij od oryginalnych kolumn (bez starych metadanych)
orig_cols = [c for c in df.columns if c not in ALL_COLS]
base = df[orig_cols].copy()
base["product_id"] = base["product_id"].astype(int)

merged = base.merge(clean_meta, on="product_id", how="left")
merged.to_csv(OUTPUT_CSV, index=False)

print(f"Zapisano {len(merged)} wierszy do '{OUTPUT_CSV}'")
merged[["product_id", "product_name"] + ALL_COLS].head(3)
# Out:
# Zapisano 100 wierszy do 'zurada_products_with_metadata_cleaned.csv'
#    product_id           product_name  \
# 0           1  Zurada Lśniąca Pianka
# 1           2   Zurada Szklany Blask
# 2           3    Zurada Tłuszcz Stop
#
#                               dozwolone_powierzchnie  \
# 0  ["wszystkie powierzchnie", "tworzywa sztuczne"...
# 1  ["szkło", "gładkie powierzchnie", "porcelana",...
# 2  ["blaty", "podłogi", "ściany", "naczynia", "ga...
#
#                               odradzane_powierzchnie  \
# 0                                                 []
# 1  ["powierzchnie wrażliwe na alkohol", "rozgrzan...
# 2  ["aluminium", "miedź", "powierzchnie malowane"...
#
#                           metoda_mycia zgodnosc_i_certyfikaty  \
# 0             ["ręczne", "natryskowe"]                     []
# 1  ["ręczne", "natryskowe", "pianowe"]       ["IFRA", "RSPO"]
# 2                ["pianowe", "ręczne"]                     []
#
#                                      ostrzezenia_bhp odczyn_ph
# 0   ["spłukać wodą pitną", "wytrzeć szkło do sucha"]       NaN
# 1  ["unikać alkoholu", "unikać gorąca i słońca", ...       NaN
# 2       ["dobrać stężenie", "wykonać próbę wstępną"]       NaN

# %%
# ── Walidacja: nowe rozkłady wartości ────────────────────────────────────────
from collections import Counter

for col in LIST_COLS:
    counter = Counter()
    for v in merged[col].dropna():
        try:
            counter.update(json.loads(v))
        except Exception:
            pass
    print(f"\n=== {col} ({len(counter)} canonical) ===")
    for val, cnt in counter.most_common(15):
        print(f"  {cnt:3d}x  {val}")

print(f"\n=== odczyn_ph ===")
print(merged["odczyn_ph"].value_counts().to_string())
# Out:
# === dozwolone_powierzchnie (201 canonical) ===
#    28x  tworzywa sztuczne
#    21x  stal nierdzewna
#    19x  szkło
#    19x  powierzchnie ponadpodłogowe
#    17x  podłogi
#    14x  porcelana
#    14x  zmywalne powierzchnie
#    12x  naczynia
#     9x  garnki
#     9x  ceramika
#     9x  powierzchnie sanitarne
#     9x  wanny
#     9x  gres
#     9x  lakier
#     8x  meble
#
# === odradzane_powierzchnie (48 canonical) ===
#    25x  aluminium
#    14x  powierzchnie wrażliwe na wodę
#    12x  miedź
#    10x  powierzchnie malowane
#    10x  powierzchnie lakierowane
#     8x  mosiądz
#     7x  powierzchnie wrażliwe na zasady
#     5x  powierzchnie wrażliwe na alkohol
#     5x  rozgrzane powierzchnie
#     5x  powierzchnie zabezpieczone polimerem
#     5x  powierzchnie wrażliwe na kwasy
#     4x  drewno
#     4x  panele
#     3x  piekarniki z automatycznym myciem
#     3x  zmywarki domowe
#
# === metoda_mycia (23 canonical) ===
#    80x  ręczne
#    40x  pianowe
#    26x  maszynowe
#    22x  ciśnieniowe
#    20x  natryskowe
#     6x  systemy dozujące
#     5x  CIP
#     4x  myjnie samochodowe
#     4x  automatyczne
#     3x  zmywarki
#     3x  przecieranie ściereczką
#     2x  mopowanie
#     2x  pranie
#     2x  aplikacja gąbką
#     1x  szorowanie
#
# === zgodnosc_i_certyfikaty (20 canonical) ===
#    37x  RSPO
#    33x  IFRA
#    10x  HACCP
#     4x  ekologiczny
#     4x  bez fosforanów
#     3x  opakowanie do recyklingu
#     2x  bez SLS
#     2x  bez dodecylobenzenosulfonianów
#     2x  bez EDTA
#     2x  bez NTA
#     2x  opakowanie do ponownego napełnienia
#     2x  przebadany dermatologicznie
#     1x  bez EDTA/NTA/SLS/fosforanów/dodecylobenzenosulfonianów
#     1x  nie powoduje eutrofizacji
#     1x  składniki roślinne
#
# === ostrzezenia_bhp (63 canonical) ===
#    30x  wykonać próbę wstępną
#    10x  karta charakterystyki
#     7x  unikać kontaktu z oczami
#     6x  spłukać czystą wodą
#     5x  unikać gorąca i słońca
#     4x  spłukać wodą pitną
#     4x  instrukcja urządzenia
#     4x  umyć ręce
#     3x  dobrać stężenie
#     3x  unikać wody
#     3x  zalecenia producenta zmywarki
#     3x  nie dopuścić do wyschnięcia
#     3x  rękawice ochronne
#     3x  okulary ochronne
#     3x  zalecenia producenta
#
# === odczyn_ph ===
# odczyn_ph
# neutralny          7
# zasadowy           5
# lekko zasadowy     5
# silnie zasadowy    4
# kwaśny             4

# %%
# ── Podgląd konkretnego produktu ─────────────────────────────────────────────
PRODUCT_ID = 45

row = merged[merged["product_id"] == PRODUCT_ID].iloc[0]
print(f"=== {row['product_name']} (ID {PRODUCT_ID}) ===")
for col in ALL_COLS:
    val = row[col]
    try:
        val = json.loads(val)
    except Exception:
        pass
    print(f"\n{col}:")
    if isinstance(val, list):
        for item in val:
            print(f"  • {item}")
    else:
        print(f"  {val}")
# Out:
# === Zurada Odtłuszczacz Moc (ID 45) ===
#
# dozwolone_powierzchnie:
#   • blaty
#   • podłogi
#   • ściany
#   • naczynia
#   • narzędzia
#   • części samochodowe
#   • zatłuszczone powierzchnie
#   • sufity
#   • przedmioty
#   • wrażliwe na alkalia
#   • aluminium
#   • kontakt z żywnością
#
# odradzane_powierzchnie:
#
# metoda_mycia:
#   • ręczne
#   • ciśnieniowe
#   • maszynowe
#   • CIP
#
# zgodnosc_i_certyfikaty:
#   • do przemysłu spożywczego
#
# ostrzezenia_bhp:
#   • spłukać wodą pitną
#   • wykonać próbę wstępną
#
# odczyn_ph:
#   nan
