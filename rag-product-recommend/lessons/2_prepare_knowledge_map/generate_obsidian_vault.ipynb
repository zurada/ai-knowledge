# %% [markdown]
# # Generowanie Obsidian Vault — Katalog Zurada
#
# Tworzy vault z plików MD z linkami `[[wikilink]]` dla grafu Obsidian.
#
# **Struktura:**
# - `Produkty/` — 100 stron produktów
# - `Powierzchnie/` — dozwolone powierzchnie
# - `Odradzane/` — odradzane powierzchnie
# - `Metody/` — metody mycia
# - `Certyfikaty/` — certyfikaty i normy
# - `pH/` — odczyn pH
# - `BHP/` — ostrzeżenia BHP
# - `Kategorie/` — kategorie sklepowe
# - `_Index.md` — strona główna

# %%
import json, re, shutil
import pandas as pd
from pathlib import Path
from collections import defaultdict

BASE_DIR     = Path('.')
PRODUCTS_CSV = BASE_DIR / 'zurada_products_with_metadata_cleaned.csv'
DESC_CSV     = BASE_DIR / 'zurada_canonical_descriptions.csv'
VAULT_DIR    = BASE_DIR / 'zurada_vault'

COL_TO_FOLDER = {
    'dozwolone_powierzchnie': 'Powierzchnie',
    'odradzane_powierzchnie': 'Odradzane',
    'metoda_mycia':           'Metody',
    'zgodnosc_i_certyfikaty': 'Certyfikaty',
    'odczyn_ph':              'pH',
    'ostrzezenia_bhp':        'BHP',
}
COL_LABEL = {
    'dozwolone_powierzchnie': 'Dozwolone powierzchnie',
    'odradzane_powierzchnie': 'Odradzane powierzchnie',
    'metoda_mycia':           'Metody mycia',
    'zgodnosc_i_certyfikaty': 'Certyfikaty',
    'odczyn_ph':              'pH',
    'ostrzezenia_bhp':        'Ostrzeżenia BHP',
}
PROD_FOLDER = 'Produkty'
CAT_FOLDER  = 'Kategorie'

print('Konfiguracja gotowa.')
# Out:
# Konfiguracja gotowa.

# %%
def safe(name: str) -> str:
    name = str(name).strip()
    name = re.sub(r'[<>:"/\\|?*\x00-\x1f]', '-', name)
    name = name.strip('-').strip('.')
    return name[:120] or 'unnamed'

def parse_list(val) -> list:
    if pd.isna(val) or str(val).strip() == '':
        return []
    try:
        p = json.loads(val)
        return p if isinstance(p, list) else [str(p)]
    except Exception:
        return [str(val)]

def parse_cats(val) -> list:
    s = str(val) if not pd.isna(val) else ''
    return [c.strip() for c in s.split(',') if c.strip()]

def wikilink(folder: str, value: str) -> str:
    return f'[[{folder}/{safe(value)}|{value}]]'

def write_md(path: Path, content: str):
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(content, encoding='utf-8')

print('Funkcje pomocnicze gotowe.')
# Out:
# Funkcje pomocnicze gotowe.

# %%
df = pd.read_csv(PRODUCTS_CSV)
print(f'Produkty: {len(df)}')

desc_df = pd.read_csv(DESC_CSV)
descriptions = {
    (row['value'], row['column']): row['description']
    for _, row in desc_df.iterrows()
    if pd.notna(row.get('description')) and str(row['description']).strip()
}
print(f'Opisy: {len(descriptions)} wpisow')

if VAULT_DIR.exists():
    shutil.rmtree(VAULT_DIR)
    print('Usunieto stary vault.')
VAULT_DIR.mkdir()
print(f'Vault: {VAULT_DIR.resolve()}')
# Out:
# Produkty: 100
# Opisy: 360 wpisow
# Vault: /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/lessons/2_prepare_knowledge_map/zurada_vault

# %% [markdown]
# ## Krok 1 — Zbierz powiązania produkt ↔ koncept

# %%
# concept_products[(folder, safe_value)] = [product_name, ...]
concept_products = defaultdict(list)

for _, row in df.iterrows():
    pname = row['product_name']
    for col, folder in COL_TO_FOLDER.items():
        for v in parse_list(row.get(col)):
            if v:
                concept_products[(folder, safe(v))].append(pname)
    for cat in parse_cats(row.get('categories', '')):
        concept_products[(CAT_FOLDER, safe(cat))].append(pname)

print(f'Konceptow w grafie: {len(concept_products)}')
# Out:
# Konceptow w grafie: 457

# %%
concept_products
# Out:
# defaultdict(list,
#             {('Powierzchnie',
#               'wszystkie powierzchnie'): ['Zurada Lśniąca Pianka', 'Zurada Naczynia Generic Cleaning', 'Zurada Silnik Moc', 'Zurada Owad Stop'],
#              ('Powierzchnie', 'tworzywa sztuczne'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Total Clean',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Turbo Czystość',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Czysta Posadzka',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Kwas Pro',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Kryształ',
#               'Zurada Silnik Moc',
#               'Zurada Posadzka Lux',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Woskowy Blask',
#               'Zurada Opona Blask',
#               'Zurada Pianka',
#               'Zurada Fala Czystości',
#               'Zurada Kropla Blasku'],
#              ('Powierzchnie', 'meble'): ['Zurada Lśniąca Pianka',
#               'Zurada Kuchnia Czysta',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Stal Błysk',
#               'Zurada Meble Blask'],
#              ('Powierzchnie', 'blaty'): ['Zurada Lśniąca Pianka',
#               'Zurada Tłuszcz Stop',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Błyszcząca Piana',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'okapy'): ['Zurada Lśniąca Pianka',
#               'Zurada Kuchnia Czysta',
#               'Zurada Piana Moc',
#               'Zurada ŻarMoc'],
#              ('Powierzchnie', 'metal'): ['Zurada Lśniąca Pianka',
#               'Zurada Total Clean',
#               'Zurada Turbo Czystość',
#               'Zurada Piankowy Blask',
#               'Zurada Silnik Moc',
#               'Zurada Fala Czystości'],
#              ('Powierzchnie', 'kontakt z żywnością'): ['Zurada Lśniąca Pianka',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Chlor Piana'],
#              ('Powierzchnie', 'szkło'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Kryształ',
#               'Zurada Cytrusowy Blask',
#               'Zurada Owad Stop',
#               'Zurada Szybki Blask',
#               'Zurada Odkamień Proszek'],
#              ('Metody', 'ręczne'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Total Clean',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Posadzka',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Alka Czystość',
#               'Zurada Sanitar Błysk',
#               'Zurada AlkaMoc',
#               'Zurada Aktywna Piana',
#               'Zurada Alka Moc',
#               'Zurada Kwas Pro',
#               'Zurada Neutral Błysk',
#               'Zurada Lśniąca Piana',
#               'Zurada Klar Pro',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Pianka Turbo',
#               'Zurada Kryształ',
#               'Zurada Piana Błysk',
#               'Zurada Motor Moc',
#               'Zurada Silnik Moc',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Posadzka Lux',
#               'Zurada Drewno Blask',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Polimer Błysk',
#               'Zurada Kwiat Podłogi',
#               'Zurada Przepływ',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Gastro Piana',
#               'Zurada Floor Fresh',
#               'Zurada Alkali Floor',
#               'Zurada Czyste Dłonie',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Strip Moc',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Cytrusowy Blask',
#               'Zurada Piana Delikatna',
#               'Zurada Mydło Dłoni',
#               'Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada Winogronowa Piana',
#               'Zurada Meble Blask',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Car Piana',
#               'Zurada Truck Piana',
#               'Zurada Woskowy Blask',
#               'Zurada Krwawy Blask',
#               'Zurada Owad Stop',
#               'Zurada Szybki Blask',
#               'Zurada Pianka',
#               'Zurada Tapicer Max',
#               'Zurada Odkamień Piana',
#               'Zurada Moc Czystości',
#               'Zurada Karoseria Blask',
#               'Zurada Kropla Blasku',
#               'Zurada Hydro Błysk',
#               'Zurada Lustrzany Blask'],
#              ('Metody', 'natryskowe'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Piana Moc',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Aktywna Piana',
#               'Zurada Kwas Pro',
#               'Zurada Klar Pro',
#               'Zurada Silnik Moc',
#               'Zurada Stal Błysk',
#               'Zurada Gastro Piana',
#               'Zurada Aromat Pro',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Kwasowa Moc',
#               'Zurada Krwawy Blask',
#               'Zurada Opona Blask',
#               'Zurada Owad Stop',
#               'Zurada Szybki Blask'],
#              ('BHP', 'spłukać wodą pitną'): ['Zurada Lśniąca Pianka',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Gastro Piana'],
#              ('BHP', 'wytrzeć szkło do sucha'): ['Zurada Lśniąca Pianka'],
#              ('Kategorie', 'horeca-hotele'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Podłoga Fresh',
#               'Zurada Doza',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Sanitar Błysk',
#               'Zurada Alka Moc',
#               'Zurada Neutral Błysk',
#               'Zurada Lśniąca Piana',
#               'Zurada Klar Pro',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Drewno Blask',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Polimer Błysk',
#               'Zurada Przepływ',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Gastro Piana',
#               'Zurada Aromat Pro',
#               'Zurada Floor Fresh',
#               'Zurada Alkali Floor',
#               'Zurada Czyste Dłonie',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Strip Moc',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro',
#               'Zurada Piana Delikatna',
#               'Zurada Mydło Dłoni',
#               'Zurada Chlor Piana',
#               'Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax',
#               'Zurada Meble Blask',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc'],
#              ('Kategorie', 'szkoly'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Podłoga Fresh',
#               'Zurada Doza',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Sanitar Błysk',
#               'Zurada Alka Moc',
#               'Zurada Neutral Błysk',
#               'Zurada Lśniąca Piana',
#               'Zurada Klar Pro',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Piana Błysk',
#               'Zurada Drewno Blask',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Polimer Błysk',
#               'Zurada Przepływ',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Gastro Piana',
#               'Zurada Aromat Pro',
#               'Zurada Floor Fresh',
#               'Zurada Alkali Floor',
#               'Zurada Czyste Dłonie',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Strip Moc',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro',
#               'Zurada Mydło Dłoni',
#               'Zurada Chlor Piana',
#               'Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax',
#               'Zurada Meble Blask',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc'],
#              ('Kategorie', 'firmy-sprzatajace'): ['Zurada Lśniąca Pianka',
#               'Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Podłoga Fresh',
#               'Zurada Doza',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Sanitar Błysk',
#               'Zurada Alka Moc',
#               'Zurada Neutral Błysk',
#               'Zurada Lśniąca Piana',
#               'Zurada Klar Pro',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Piana Błysk',
#               'Zurada Drewno Blask',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Polimer Błysk',
#               'Zurada Przepływ',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Gastro Piana',
#               'Zurada Aromat Pro',
#               'Zurada Floor Fresh',
#               'Zurada Alkali Floor',
#               'Zurada Czyste Dłonie',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Strip Moc',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro',
#               'Zurada Mydło Dłoni',
#               'Zurada Chlor Piana',
#               'Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax',
#               'Zurada Meble Blask',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc'],
#              ('Kategorie',
#               'higiena-powierzchni-firmy-sprzatajace'): ['Zurada Lśniąca Pianka', 'Zurada Szklany Blask', 'Zurada Czysta Moc', 'Zurada Neutral Błysk', 'Zurada Błyszcząca Piana', 'Zurada Szkło Błysk', 'Zurada Stal Błysk', 'Zurada Moc Czystości'],
#              ('Kategorie', 'odtluszczanie-catering'): ['Zurada Lśniąca Pianka',
#               'Zurada Tłuszcz Stop',
#               'Zurada Odtłuszczacz Moc'],
#              ('Kategorie', 'higiena-urzadzen'): ['Zurada Lśniąca Pianka',
#               'Zurada Piana Moc',
#               'Zurada Łazienkowy Blask',
#               'Zurada Klar Pro',
#               'Zurada Stal Błysk',
#               'Zurada Gastro Piana',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc',
#               'Zurada Moc Czystości'],
#              ('Kategorie',
#               'higiena-urzadzen-instytucje'): ['Zurada Lśniąca Pianka', 'Zurada Piana Moc', 'Zurada Łazienkowy Blask', 'Zurada Klar Pro', 'Zurada Stal Błysk', 'Zurada Gastro Piana', 'Zurada PiecMax', 'Zurada Kwasowa Moc', 'Zurada Płukacz Pro', 'Zurada Odkamień Piana', 'Zurada Gastro Moc', 'Zurada Moc Czystości'],
#              ('Kategorie',
#               'higiena-powierzchni-instytucje'): ['Zurada Lśniąca Pianka', 'Zurada Szklany Blask', 'Zurada Piana Moc', 'Zurada Czysta Moc', 'Zurada Neutral Błysk', 'Zurada Błyszcząca Piana', 'Zurada Szkło Błysk', 'Zurada Stal Błysk', 'Zurada Moc Czystości'],
#              ('Kategorie',
#               'higiena-urzadzen-firmy-sprzatajace'): ['Zurada Lśniąca Pianka', 'Zurada Piana Moc', 'Zurada Łazienkowy Blask', 'Zurada Klar Pro', 'Zurada Stal Błysk', 'Zurada Gastro Piana', 'Zurada PiecMax', 'Zurada Kwasowa Moc', 'Zurada Płukacz Pro', 'Zurada Odkamień Piana', 'Zurada Gastro Moc', 'Zurada Moc Czystości'],
#              ('Kategorie',
#               'higiena-powierzchni-catering'): ['Zurada Lśniąca Pianka', 'Zurada Szklany Blask', 'Zurada Czysta Moc', 'Zurada Neutral Błysk', 'Zurada Błyszcząca Piana', 'Zurada Szkło Błysk', 'Zurada Stal Błysk', 'Zurada Moc Czystości'],
#              ('Kategorie',
#               'odtluszczanie-instytucje'): ['Zurada Lśniąca Pianka', 'Zurada Tłuszcz Stop'],
#              ('Kategorie',
#               'odtluszczanie-firmy-sprzatajace'): ['Zurada Lśniąca Pianka', 'Zurada Tłuszcz Stop'],
#              ('Powierzchnie',
#               'gładkie powierzchnie'): ['Zurada Szklany Blask'],
#              ('Powierzchnie', 'porcelana'): ['Zurada Szklany Blask',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Kwas Pro',
#               'Zurada Kryształ',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Cytrusowy Blask'],
#              ('Powierzchnie', 'stal nierdzewna'): ['Zurada Szklany Blask',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Kwas Pro',
#               'Zurada Klar Pro',
#               'Zurada Szkło Błysk',
#               'Zurada Kryształ',
#               'Zurada Stal Błysk',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Cytrusowy Blask',
#               'Zurada Płukacz Pro',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'glazura'): ['Zurada Szklany Blask',
#               'Zurada Alka Moc',
#               'Zurada Szkło Błysk',
#               'Zurada Błysk Podłóg',
#               'Zurada Pomarańczowa Moc'],
#              ('Powierzchnie',
#               'powierzchnie ponadpodłogowe'): ['Zurada Szklany Blask', 'Zurada Bruk Moc', 'Zurada Lśniąca Podłoga', 'Zurada Sanibłysk', 'Zurada Bruk Turbo', 'Zurada Nabłyszcz Pro', 'Zurada Łazienkowy Blask', 'Zurada Czysta Moc', 'Zurada Piankowy Blask', 'Zurada Neutral Błysk', 'Zurada Błyszcząca Piana', 'Zurada Polimer Błysk', 'Zurada Kwiat Podłogi', 'Zurada Stal Błysk', 'Zurada Chłodny Błysk', 'Zurada Czysty Blask', 'Zurada Płukacz Pro', 'Zurada Woskowy Blask', 'Zurada Karoseria Blask'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na alkohol'): ['Zurada Szklany Blask', 'Zurada Podłoga Pro', 'Zurada Piana Błysk', 'Zurada Chłodny Błysk', 'Zurada Floor Fresh'],
#              ('Odradzane', 'rozgrzane powierzchnie'): ['Zurada Szklany Blask',
#               'Zurada Aktywna Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Woskowy Blask',
#               'Zurada Kropla Blasku'],
#              ('Metody', 'pianowe'): ['Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Total Clean',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Aktywna Piana',
#               'Zurada ŻarMoc',
#               'Zurada Neutral Błysk',
#               'Zurada Lśniąca Piana',
#               'Zurada Błyszcząca Piana',
#               'Zurada Pianka Turbo',
#               'Zurada Motor Moc',
#               'Zurada Silnik Moc',
#               'Zurada Polimer Błysk',
#               'Zurada Kwiat Podłogi',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Gastro Piana',
#               'Zurada Płukacz Pro',
#               'Zurada Piana Delikatna',
#               'Zurada Chlor Piana',
#               'Zurada Tkaninex',
#               'Zurada PiankoMax',
#               'Zurada Winogronowa Piana',
#               'Zurada Auto Piana',
#               'Zurada Car Piana',
#               'Zurada Truck Piana',
#               'Zurada Woskowy Blask',
#               'Zurada Pianka',
#               'Zurada Tapicer Max',
#               'Zurada Odkamień Piana',
#               'Zurada Karoseria Blask'],
#              ('Certyfikaty', 'IFRA'): ['Zurada Szklany Blask',
#               'Zurada Kuchnia Czysta',
#               'Zurada Bruk Moc',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Bruk Turbo',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Posadzka',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Kryształ',
#               'Zurada Piana Błysk',
#               'Zurada Posadzka Lux',
#               'Zurada Błysk Podłóg',
#               'Zurada Polimer Błysk',
#               'Zurada Kwiat Podłogi',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Floor Fresh',
#               'Zurada Płukacz Pro',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel',
#               'Zurada Woskowy Blask',
#               'Zurada Karoseria Blask'],
#              ('Certyfikaty', 'RSPO'): ['Zurada Szklany Blask',
#               'Zurada Kuchnia Czysta',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Bruk Turbo',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Posadzka',
#               'Zurada Łazienkowy Blask',
#               'Zurada Czysta Moc',
#               'Zurada Piankowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada ŻarMoc',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Kryształ',
#               'Zurada Piana Błysk',
#               'Zurada Posadzka Lux',
#               'Zurada Błysk Podłóg',
#               'Zurada Polimer Błysk',
#               'Zurada Kwiat Podłogi',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Floor Fresh',
#               'Zurada Cytrusowy Blask',
#               'Zurada Płukacz Pro',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel',
#               'Zurada Woskowy Blask',
#               'Zurada Karoseria Blask'],
#              ('BHP', 'unikać alkoholu'): ['Zurada Szklany Blask'],
#              ('BHP', 'unikać gorąca i słońca'): ['Zurada Szklany Blask',
#               'Zurada Aktywna Piana',
#               'Zurada Szkło Błysk',
#               'Zurada Woskowy Blask',
#               'Zurada Karoseria Blask'],
#              ('BHP', 'wykonać próbę wstępną'): ['Zurada Szklany Blask',
#               'Zurada Tłuszcz Stop',
#               'Zurada Podłoga Pro',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Bruk Turbo',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Moc',
#               'Zurada ŻarMoc',
#               'Zurada Neutral Błysk',
#               'Zurada Błyszcząca Piana',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada Alkali Floor',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Meble Blask',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Tapicer Max',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc',
#               'Zurada Karoseria Blask',
#               'Zurada Kropla Blasku'],
#              ('BHP', 'karta charakterystyki'): ['Zurada Szklany Blask',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Czysta Moc',
#               'Zurada Stal Błysk',
#               'Zurada Chłodny Błysk',
#               'Zurada Płukacz Pro',
#               'Zurada Meble Blask',
#               'Zurada Odkamień Proszek'],
#              ('Kategorie',
#               'mycie-szyb-i-luster-instytucje'): ['Zurada Szklany Blask', 'Zurada Szkło Błysk'],
#              ('Kategorie',
#               'mycie-szyb-i-luster-firmy-sprzatajace'): ['Zurada Szklany Blask', 'Zurada Szkło Błysk'],
#              ('Kategorie',
#               'mycie-szyb-i-luster-catering'): ['Zurada Szklany Blask', 'Zurada Szkło Błysk'],
#              ('Powierzchnie', 'podłogi'): ['Zurada Tłuszcz Stop',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Podłoga Pro',
#               'Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Posadzka',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Posadzka Lux',
#               'Zurada Błysk Podłóg',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Kwiat Podłogi',
#               'Zurada Czysty Blask',
#               'Zurada Floor Fresh',
#               'Zurada Biel Moc'],
#              ('Powierzchnie', 'ściany'): ['Zurada Tłuszcz Stop',
#               'Zurada Lśniąca Podłoga',
#               'Zurada Czysta Moc',
#               'Zurada Błyszcząca Piana',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Pomarańczowa Moc'],
#              ('Powierzchnie', 'naczynia'): ['Zurada Tłuszcz Stop',
#               'Zurada Kuchnia Czysta',
#               'Zurada Naczynia Generic Cleaning',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Odkamień Proszek',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'garnki'): ['Zurada Tłuszcz Stop',
#               'Zurada Kuchnia Czysta',
#               'Zurada Piana Moc',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada ŻarMoc',
#               'Zurada Cytrusowy Blask'],
#              ('Powierzchnie', 'blachy'): ['Zurada Tłuszcz Stop'],
#              ('Powierzchnie', 'narzędzia'): ['Zurada Tłuszcz Stop',
#               'Zurada Total Clean',
#               'Zurada Silnik Moc',
#               'Zurada Odtłuszczacz Moc'],
#              ('Powierzchnie', 'odzież robocza'): ['Zurada Tłuszcz Stop'],
#              ('Odradzane', 'aluminium'): ['Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Alka Czystość',
#               'Zurada Sanitar Błysk',
#               'Zurada AlkaMoc',
#               'Zurada Alka Moc',
#               'Zurada Kwas Pro',
#               'Zurada Błysk Podłóg',
#               'Zurada Przepływ',
#               'Zurada Gastro Piana',
#               'Zurada Alka Floor',
#               'Zurada Strip Moc',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Odkamień Piana',
#               'Zurada Gastro Moc'],
#              ('Odradzane', 'miedź'): ['Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Sanibłysk',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Sanitar Błysk',
#               'Zurada Gastro Piana',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Odkamień Piana'],
#              ('Odradzane', 'powierzchnie malowane'): ['Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Sanitar Błysk',
#               'Zurada Alka Moc',
#               'Zurada Błysk Podłóg',
#               'Zurada Gastro Piana',
#               'Zurada Alka Floor',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc'],
#              ('Odradzane', 'powierzchnie lakierowane'): ['Zurada Tłuszcz Stop',
#               'Zurada Piana Moc',
#               'Zurada Bruk Moc',
#               'Zurada Sanitar Błysk',
#               'Zurada Alka Moc',
#               'Zurada Błysk Podłóg',
#               'Zurada Gastro Piana',
#               'Zurada Alka Floor',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na zasady'): ['Zurada Tłuszcz Stop', 'Zurada Bruk Moc', 'Zurada Bruk Turbo', 'Zurada Aktywna Piana', 'Zurada Błysk Podłóg', 'Zurada Przepływ', 'Zurada Alka Floor'],
#              ('BHP', 'dobrać stężenie'): ['Zurada Tłuszcz Stop',
#               'Zurada Kwas Moc',
#               'Zurada Odkamień Proszek'],
#              ('Powierzchnie',
#               'powierzchnie kuchenne'): ['Zurada Kuchnia Czysta'],
#              ('Powierzchnie',
#               'urządzenia kuchenne'): ['Zurada Kuchnia Czysta'],
#              ('Powierzchnie', 'akcesoria kuchenne'): ['Zurada Kuchnia Czysta'],
#              ('Powierzchnie', 'stoły'): ['Zurada Kuchnia Czysta',
#               'Zurada Czysta Moc',
#               'Zurada Błyszcząca Piana',
#               'Zurada Meble Blask'],
#              ('Powierzchnie',
#               'zatłuszczone powierzchnie'): ['Zurada Kuchnia Czysta', 'Zurada Odtłuszczacz Moc'],
#              ('Certyfikaty',
#               'bez EDTA-NTA-SLS-fosforanów-dodecylobenzenosulfonianów'): ['Zurada Kuchnia Czysta'],
#              ('Kategorie',
#               'ekologiczne-produkty-eu-ecolabel'): ['Zurada Kuchnia Czysta', 'Zurada Czysta Łazienka', 'Zurada Czysta Posadzka', 'Zurada Piankowy Blask', 'Zurada ŻarMoc', 'Zurada Kryształ', 'Zurada Posadzka Lux', 'Zurada Cytrusowy Blask', 'Zurada Toaleta Żel'],
#              ('Kategorie', 'odtluszczanie'): ['Zurada Kuchnia Czysta'],
#              ('Powierzchnie', 'grille'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'piekarniki'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'piece'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Klar Pro',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc'],
#              ('Powierzchnie', 'urządzenia do kebabów'): ['Zurada Piana Moc',
#               'Zurada Gastro Piana'],
#              ('Powierzchnie', 'szyby kominkowe'): ['Zurada Piana Moc'],
#              ('Powierzchnie', 'patelnie'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Cytrusowy Blask'],
#              ('Powierzchnie', 'kuchenki'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'kominki'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc'],
#              ('Odradzane',
#               'piekarniki z automatycznym myciem'): ['Zurada Piana Moc',
#               'Zurada ŻarMoc',
#               'Zurada Gastro Piana'],
#              ('Certyfikaty', 'HACCP'): ['Zurada Piana Moc',
#               'Zurada Krystal Błysk',
#               'Zurada Alka Moc',
#               'Zurada ŻarMoc',
#               'Zurada Chłodny Błysk',
#               'Zurada Czysty Blask',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Cytrusowy Blask',
#               'Zurada Mydło Dłoni'],
#              ('Kategorie', 'higiena-piecow-catering'): ['Zurada Piana Moc',
#               'Zurada Klar Pro',
#               'Zurada Gastro Piana',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro'],
#              ('Kategorie',
#               'higiena-piecow-firmy-sprzatajace'): ['Zurada Piana Moc', 'Zurada Klar Pro', 'Zurada Gastro Piana', 'Zurada PiecMax', 'Zurada Kwasowa Moc', 'Zurada Płukacz Pro'],
#              ('Kategorie', 'higiena-piecow-instytucje'): ['Zurada Piana Moc',
#               'Zurada Klar Pro',
#               'Zurada Gastro Piana',
#               'Zurada PiecMax',
#               'Zurada Kwasowa Moc',
#               'Zurada Płukacz Pro'],
#              ('Powierzchnie', 'kostka brukowa'): ['Zurada Bruk Moc',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość'],
#              ('Powierzchnie', 'beton'): ['Zurada Bruk Moc',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość',
#               'Zurada Polimer Błysk',
#               'Zurada Strip Moc'],
#              ('Powierzchnie', 'kamień'): ['Zurada Bruk Moc',
#               'Zurada Bruk Turbo',
#               'Zurada Polimer Błysk',
#               'Zurada Strip Moc'],
#              ('Powierzchnie', 'powierzchnie zewnętrzne'): ['Zurada Bruk Moc'],
#              ('Metody', 'ciśnieniowe'): ['Zurada Bruk Moc',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Aktywna Piana',
#               'Zurada Alka Moc',
#               'Zurada Kwas Pro',
#               'Zurada Klar Pro',
#               'Zurada Pianka Turbo',
#               'Zurada Motor Moc',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Kwasowa Moc',
#               'Zurada Winogronowa Piana',
#               'Zurada Auto Piana',
#               'Zurada Car Piana',
#               'Zurada Truck Piana',
#               'Zurada Krwawy Blask',
#               'Zurada Owad Stop'],
#              ('Metody', 'szorowanie'): ['Zurada Bruk Moc'],
#              ('pH', 'zasadowy'): ['Zurada Bruk Moc',
#               'Zurada Alkali Floor',
#               'Zurada Alka Floor',
#               'Zurada Strip Moc',
#               'Zurada Truck Piana'],
#              ('BHP', 'unikać zasad'): ['Zurada Bruk Moc',
#               'Zurada Aktywna Piana'],
#              ('Kategorie', 'mycie-cisnieniowe'): ['Zurada Bruk Moc',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość'],
#              ('Powierzchnie', 'ceramika'): ['Zurada Naczynia Generic Cleaning',
#               'Zurada Zmywark Pro',
#               'Zurada Alka Czystość',
#               'Zurada AlkaMoc',
#               'Zurada Kwas Pro',
#               'Zurada Kryształ',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Cytrusowy Blask',
#               'Zurada Kamień Stop'],
#              ('Powierzchnie',
#               'aluminium'): ['Zurada Naczynia Generic Cleaning', 'Zurada Klar Pro', 'Zurada Kryształ', 'Zurada Odtłuszczacz Moc', 'Zurada Stal Błysk', 'Zurada Gastro Odtłuszcz', 'Zurada Cytrusowy Blask'],
#              ('Powierzchnie',
#               'naczynia emaliowane'): ['Zurada Naczynia Generic Cleaning'],
#              ('Powierzchnie',
#               'naczynia stalowe'): ['Zurada Naczynia Generic Cleaning'],
#              ('Powierzchnie',
#               'naczynia aluminiowe'): ['Zurada Naczynia Generic Cleaning'],
#              ('Metody', 'zanurzeniowe'): ['Zurada Naczynia Generic Cleaning'],
#              ('BHP',
#               'spłukać naczynia wodą pitną'): ['Zurada Naczynia Generic Cleaning',
#               'Zurada Cytrusowy Blask'],
#              ('Kategorie',
#               'reczne-mycie-naczyn-catering'): ['Zurada Naczynia Generic Cleaning'],
#              ('Kategorie',
#               'reczne-mycie-naczyn-instytucje'): ['Zurada Naczynia Generic Cleaning'],
#              ('Kategorie',
#               'reczne-mycie-naczyn-firmy-sprzatajace'): ['Zurada Naczynia Generic Cleaning'],
#              ('Powierzchnie',
#               'zmywalne powierzchnie'): ['Zurada Lśniąca Podłoga', 'Zurada Podłoga Pro', 'Zurada Podłoga Fresh', 'Zurada Czysta Moc', 'Zurada Piankowy Blask', 'Zurada Neutral Błysk', 'Zurada Lśniąca Piana', 'Zurada Błyszcząca Piana', 'Zurada Kryształ', 'Zurada Piana Błysk', 'Zurada Szybka Czystość', 'Zurada Pomarańczowa Moc', 'Zurada Floor Fresh', 'Zurada Chlor Piana'],
#              ('Powierzchnie', 'sufity'): ['Zurada Lśniąca Podłoga',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na wodę'): ['Zurada Lśniąca Podłoga', 'Zurada Podłoga Pro', 'Zurada Podłoga Fresh', 'Zurada Czysta Moc', 'Zurada Neutral Błysk', 'Zurada Błyszcząca Piana', 'Zurada Szkło Błysk', 'Zurada Piana Błysk', 'Zurada Drewno Blask', 'Zurada Podłoga Moc', 'Zurada Chłodny Błysk', 'Zurada Czysty Blask', 'Zurada Floor Fresh', 'Zurada Alkali Floor'],
#              ('pH', 'neutralny'): ['Zurada Lśniąca Podłoga',
#               'Zurada Neutral Błysk',
#               'Zurada Klar Pro',
#               'Zurada Drewno Blask',
#               'Zurada Gastro Odtłuszcz',
#               'Zurada Piana Delikatna',
#               'Zurada Winogronowa Piana'],
#              ('BHP', 'unikać wody'): ['Zurada Lśniąca Podłoga',
#               'Zurada Neutral Błysk',
#               'Zurada Szkło Błysk'],
#              ('Kategorie',
#               'mycie-podlog-reczne-firmy-sprzatajace'): ['Zurada Lśniąca Podłoga', 'Zurada Podłoga Fresh', 'Zurada Piana Błysk', 'Zurada Drewno Blask', 'Zurada Błysk Podłóg', 'Zurada Podłoga Moc', 'Zurada Pomarańczowa Moc', 'Zurada Kwiat Podłogi'],
#              ('Kategorie',
#               'mycie-podlog-reczne-instytucje'): ['Zurada Lśniąca Podłoga', 'Zurada Podłoga Fresh', 'Zurada Piana Błysk', 'Zurada Drewno Blask', 'Zurada Błysk Podłóg', 'Zurada Podłoga Moc', 'Zurada Pomarańczowa Moc', 'Zurada Kwiat Podłogi'],
#              ('Kategorie',
#               'mycie-podlog-reczne-catering'): ['Zurada Lśniąca Podłoga', 'Zurada Podłoga Fresh', 'Zurada Piana Błysk', 'Zurada Drewno Blask', 'Zurada Błysk Podłóg', 'Zurada Podłoga Moc', 'Zurada Pomarańczowa Moc', 'Zurada Kwiat Podłogi'],
#              ('Powierzchnie',
#               'powierzchnie błyszczące'): ['Zurada Podłoga Pro', 'Zurada Czysta Moc', 'Zurada Floor Fresh'],
#              ('Powierzchnie', 'powierzchnie szkliste'): ['Zurada Podłoga Pro',
#               'Zurada Floor Fresh'],
#              ('Odradzane',
#               'powierzchnie zabezpieczone polimerem'): ['Zurada Podłoga Pro', 'Zurada Piana Błysk', 'Zurada Czysty Blask', 'Zurada Floor Fresh', 'Zurada Alkali Floor'],
#              ('Metody', 'maszynowe'): ['Zurada Podłoga Pro',
#               'Zurada Gastro Błysk',
#               'Zurada Bruk Turbo',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Turbo Czystość',
#               'Zurada Zmywark Pro',
#               'Zurada Nabłyszcz Pro',
#               'Zurada Krystal Błysk',
#               'Zurada Podłoga Fresh',
#               'Zurada Czysta Posadzka',
#               'Zurada Alka Moc',
#               'Zurada Piana Błysk',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Posadzka Lux',
#               'Zurada Błysk Podłóg',
#               'Zurada Podłoga Moc',
#               'Zurada Kwiat Podłogi',
#               'Zurada Czysty Blask',
#               'Zurada Floor Fresh',
#               'Zurada Alkali Floor',
#               'Zurada Alka Floor',
#               'Zurada Kwas Moc',
#               'Zurada Strip Moc',
#               'Zurada Car Piana',
#               'Zurada Hydro Błysk'],
#              ('Certyfikaty', 'ekologiczny'): ['Zurada Podłoga Pro',
#               'Zurada Zmywark Pro',
#               'Zurada Czysta Posadzka',
#               'Zurada Floor Fresh'],
#              ('BHP', 'temperatura wody 20–30°C'): ['Zurada Podłoga Pro'],
#              ('Kategorie',
#               'mycie-podlog-maszynowe-firmy-sprzatajace'): ['Zurada Podłoga Pro', 'Zurada Alka Moc', 'Zurada Podłoga Moc', 'Zurada Kwiat Podłogi', 'Zurada Czysty Blask', 'Zurada Floor Fresh', 'Zurada Alkali Floor', 'Zurada Alka Floor', 'Zurada Kwas Moc', 'Zurada Strip Moc'],
#              ('Kategorie',
#               'mycie-podlog-maszynowe-instytucje'): ['Zurada Podłoga Pro', 'Zurada Alka Moc', 'Zurada Podłoga Moc', 'Zurada Kwiat Podłogi', 'Zurada Czysty Blask', 'Zurada Floor Fresh', 'Zurada Alkali Floor', 'Zurada Alka Floor', 'Zurada Kwas Moc', 'Zurada Strip Moc'],
#              ('Kategorie',
#               'mycie-podlog-maszynowe-catering'): ['Zurada Podłoga Pro', 'Zurada Alka Moc', 'Zurada Podłoga Moc', 'Zurada Kwiat Podłogi', 'Zurada Czysty Blask', 'Zurada Floor Fresh', 'Zurada Alkali Floor', 'Zurada Alka Floor', 'Zurada Kwas Moc', 'Zurada Strip Moc'],
#              ('Powierzchnie', 'łazienki'): ['Zurada Sanibłysk',
#               'Zurada Sanitar Błysk'],
#              ('Powierzchnie', 'toalety'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Sanitar Błysk',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel'],
#              ('Powierzchnie', 'powierzchnie sanitarne'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Pomarańczowa Moc',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel'],
#              ('Powierzchnie', 'kabiny prysznicowe'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Toaleta Żel'],
#              ('Powierzchnie', 'wanny'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'brodziki'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'umywalki'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Toaleta Żel',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'pisuary'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop',
#               'Zurada Toaleta Żel'],
#              ('Powierzchnie', 'armatura'): ['Zurada Sanibłysk',
#               'Zurada Czysta Łazienka',
#               'Zurada Sanit Żel',
#               'Zurada Łazienkowy Blask',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Toaleta Żel'],
#              ('Powierzchnie', 'fugi'): ['Zurada Sanibłysk',
#               'Zurada Sanitar Błysk',
#               'Zurada Pomarańczowa Moc'],
#              ('Odradzane', 'mosiądz'): ['Zurada Sanibłysk',
#               'Zurada Gastro Błysk',
#               'Zurada Twarda Woda',
#               'Zurada Biel Pro',
#               'Zurada Sanitar Błysk',
#               'Zurada Gastro Piana',
#               'Zurada PiecMax',
#               'Zurada Odkamień Piana'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na kwasy'): ['Zurada Sanibłysk', 'Zurada Sanit Żel', 'Zurada Sanitar Błysk', 'Zurada Kwas Moc', 'Zurada Kamień Stop'],
#              ('Odradzane', 'fugi o nietrwałym kolorze'): ['Zurada Sanibłysk'],
#              ('BHP', 'spłukać po działaniu'): ['Zurada Sanibłysk'],
#              ('BHP', 'unikać kwasów i metali'): ['Zurada Sanibłysk'],
#              ('Kategorie',
#               'higiena-sanitariatow-instytucje'): ['Zurada Sanibłysk', 'Zurada Sanit Żel', 'Zurada Łazienkowy Blask', 'Zurada Sanitar Błysk', 'Zurada Biel Moc', 'Zurada Kamień Stop', 'Zurada Odkamień Piana'],
#              ('Kategorie',
#               'higiena-sanitariatow-firmy-sprzatajace'): ['Zurada Sanibłysk', 'Zurada Sanit Żel', 'Zurada Łazienkowy Blask', 'Zurada Sanitar Błysk', 'Zurada Biel Moc', 'Zurada Kamień Stop', 'Zurada Odkamień Piana'],
#              ('Kategorie', 'higiena-toalet-instytucje'): ['Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop'],
#              ('Kategorie',
#               'higiena-toalet-firmy-sprzatajace'): ['Zurada Sanibłysk', 'Zurada Sanit Żel', 'Zurada Sanitar Błysk', 'Zurada Biel Moc', 'Zurada Kamień Stop'],
#              ('Kategorie',
#               'higiena-sanitariatow-catering'): ['Zurada Sanibłysk', 'Zurada Sanit Żel', 'Zurada Łazienkowy Blask', 'Zurada Sanitar Błysk', 'Zurada Biel Moc', 'Zurada Kamień Stop', 'Zurada Odkamień Piana'],
#              ('Kategorie', 'higiena-toalet'): ['Zurada Sanibłysk',
#               'Zurada Sanit Żel',
#               'Zurada Sanitar Błysk',
#               'Zurada Biel Moc',
#               'Zurada Kamień Stop'],
#              ('Kategorie', 'higiena-sanitariatow'): ['Zurada Czysta Łazienka',
#               'Zurada Toaleta Żel'],
#              ('BHP', 'spłukać czystą wodą'): ['Zurada Sanit Żel',
#               'Zurada Bruk Turbo',
#               'Zurada Turbo Czystość',
#               'Zurada Kamień Stop',
#               'Zurada Odkamień Piana',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'samochody'): ['Zurada Total Clean',
#               'Zurada Aktywna Piana',
#               'Zurada Winogronowa Piana',
#               'Zurada Auto Piana',
#               'Zurada Car Piana',
#               'Zurada Truck Piana'],
#              ('Powierzchnie',
#               'zewnętrzne powierzchnie pojazdów'): ['Zurada Total Clean', 'Zurada Pianka Turbo', 'Zurada Auto Piana', 'Zurada Truck Piana', 'Zurada Woskowy Blask', 'Zurada Kropla Blasku', 'Zurada Lustrzany Blask'],
#              ('Powierzchnie',
#               'wewnętrzne powierzchnie pojazdów'): ['Zurada Total Clean', 'Zurada Woskowy Blask', 'Zurada Kropla Blasku'],
#              ('Powierzchnie', 'guma'): ['Zurada Total Clean',
#               'Zurada Silnik Moc',
#               'Zurada Strip Moc',
#               'Zurada Opona Blask'],
#              ('Powierzchnie', 'silniki'): ['Zurada Total Clean',
#               'Zurada Motor Moc',
#               'Zurada Silnik Moc'],
#              ('Kategorie', 'chemia-samochodowa'): ['Zurada Total Clean',
#               'Zurada Alka Moc',
#               'Zurada Pianka Turbo',
#               'Zurada Motor Moc',
#               'Zurada Silnik Moc',
#               'Zurada Odtłuszczacz Moc',
#               'Zurada Tkaninex',
#               'Zurada PiankoMax',
#               'Zurada Winogronowa Piana',
#               'Zurada Auto Piana',
#               'Zurada Car Piana',
# ...
#               'Zurada Szybki Blask',
#               'Zurada Pianka'],
#              ('Powierzchnie',
#               'części samochodowe'): ['Zurada Odtłuszczacz Moc', 'Zurada Winogronowa Piana'],
#              ('Powierzchnie', 'przedmioty'): ['Zurada Odtłuszczacz Moc',
#               'Zurada Szybka Czystość',
#               'Zurada Chlor Piana'],
#              ('Powierzchnie',
#               'wrażliwe na alkalia'): ['Zurada Odtłuszczacz Moc'],
#              ('Certyfikaty',
#               'do przemysłu spożywczego'): ['Zurada Odtłuszczacz Moc'],
#              ('Kategorie', 'mycie-podlog-reczne'): ['Zurada Posadzka Lux'],
#              ('Powierzchnie', 'panele'): ['Zurada Drewno Blask',
#               'Zurada Kwiat Podłogi'],
#              ('Powierzchnie', 'parkiety'): ['Zurada Drewno Blask'],
#              ('Odradzane',
#               'niezaimpregnowane drewno'): ['Zurada Drewno Blask'],
#              ('BHP', 'unikać drewna i wody'): ['Zurada Drewno Blask'],
#              ('Powierzchnie', 'granit'): ['Zurada Błysk Podłóg',
#               'Zurada Alka Floor'],
#              ('Powierzchnie', 'podłogi zabrudzone'): ['Zurada Podłoga Moc'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na odtłuszczacze'): ['Zurada Podłoga Moc'],
#              ('Certyfikaty', 'PN-EN 13036-4'): ['Zurada Podłoga Moc'],
#              ('BHP', 'rozcieńczyć według zabrudzenia'): ['Zurada Podłoga Moc',
#               'Zurada Alka Floor',
#               'Zurada Winogronowa Piana'],
#              ('Powierzchnie', 'maszyny'): ['Zurada Szybka Czystość',
#               'Zurada Stal Błysk'],
#              ('Powierzchnie',
#               'ciągi technologiczne'): ['Zurada Szybka Czystość', 'Zurada Chlor Piana'],
#              ('Kategorie',
#               'dezynfekcja-powierzchni-i-urzadzen-instytucje'): ['Zurada Szybka Czystość', 'Zurada Chlor Piana'],
#              ('Kategorie',
#               'dezynfekcja-powierzchni-i-urzadzen-firmy-sprzatajace'): ['Zurada Szybka Czystość',
#               'Zurada Chlor Piana'],
#              ('Kategorie',
#               'dezynfekcja-powierzchni-i-urzadzen'): ['Zurada Szybka Czystość', 'Zurada Chlor Piana'],
#              ('Powierzchnie', 'piwnice'): ['Zurada Pomarańczowa Moc'],
#              ('Powierzchnie', 'komórki'): ['Zurada Pomarańczowa Moc'],
#              ('Powierzchnie', 'klatki schodowe'): ['Zurada Pomarańczowa Moc'],
#              ('BHP', 'zalecane dozowanie'): ['Zurada Pomarańczowa Moc'],
#              ('Powierzchnie', 'wykładziny PVC'): ['Zurada Polimer Błysk'],
#              ('Powierzchnie', 'winyl'): ['Zurada Polimer Błysk',
#               'Zurada Kwiat Podłogi',
#               'Zurada Woskowy Blask',
#               'Zurada Kropla Blasku'],
#              ('Powierzchnie', 'kauczuk'): ['Zurada Polimer Błysk'],
#              ('Powierzchnie', 'epoksyd'): ['Zurada Polimer Błysk'],
#              ('Kategorie',
#               'zabezpieczanie-i-pielegnacja-podlog-firmy-sprzatajace'): ['Zurada Polimer Błysk',
#               'Zurada Strip Moc'],
#              ('Kategorie',
#               'zabezpieczanie-i-pielegnacja-podlog-instytucje'): ['Zurada Polimer Błysk', 'Zurada Strip Moc'],
#              ('Kategorie',
#               'zabezpieczanie-i-pielegnacja-podlog'): ['Zurada Polimer Błysk', 'Zurada Strip Moc'],
#              ('Powierzchnie', 'marmur'): ['Zurada Kwiat Podłogi'],
#              ('Powierzchnie', 'twarde powierzchnie'): ['Zurada Kwiat Podłogi'],
#              ('Powierzchnie', 'syfony'): ['Zurada Przepływ'],
#              ('Powierzchnie', 'rury'): ['Zurada Przepływ'],
#              ('Powierzchnie', 'odpływy'): ['Zurada Przepływ'],
#              ('Powierzchnie', 'kratki kanalizacyjne'): ['Zurada Przepływ'],
#              ('Kategorie', 'udraznianie-rur-i-odplywow'): ['Zurada Przepływ'],
#              ('Kategorie',
#               'udraznianie-rur-i-odplywow-instytucje'): ['Zurada Przepływ'],
#              ('Kategorie',
#               'udraznianie-rur-i-odplywow-firmy-sprzatajace'): ['Zurada Przepływ'],
#              ('Powierzchnie', 'stal kwasoodporna'): ['Zurada Stal Błysk'],
#              ('Powierzchnie', 'windy'): ['Zurada Stal Błysk'],
#              ('Powierzchnie', 'balustrady'): ['Zurada Stal Błysk'],
#              ('Kategorie', 'stal-nierdzewna'): ['Zurada Stal Błysk'],
#              ('Powierzchnie', 'lodówki'): ['Zurada Chłodny Błysk'],
#              ('Powierzchnie', 'witryny chłodnicze'): ['Zurada Chłodny Błysk'],
#              ('Powierzchnie', 'pojemniki szklane'): ['Zurada Chłodny Błysk'],
#              ('Powierzchnie',
#               'pojemniki plastikowe'): ['Zurada Chłodny Błysk'],
#              ('Powierzchnie', 'uszczelki'): ['Zurada Chłodny Błysk'],
#              ('Kategorie',
#               'higiena-lodowek-instytucje'): ['Zurada Chłodny Błysk'],
#              ('Kategorie',
#               'higiena-lodowek-firmy-sprzatajace'): ['Zurada Chłodny Błysk'],
#              ('Kategorie', 'higiena-lodowek'): ['Zurada Chłodny Błysk'],
#              ('Powierzchnie', 'gofrownice'): ['Zurada Gastro Piana'],
#              ('Powierzchnie', 'naleśnikarki'): ['Zurada Gastro Piana'],
#              ('Powierzchnie', 'tostery'): ['Zurada Gastro Piana'],
#              ('Powierzchnie', 'opiekacze'): ['Zurada Gastro Piana'],
#              ('Powierzchnie', 'bemary'): ['Zurada Gastro Piana'],
#              ('Powierzchnie', 'ciepłe powierzchnie'): ['Zurada Gastro Piana'],
#              ('Kategorie',
#               'odswiezacze-powietrza-instytucje'): ['Zurada Aromat Pro'],
#              ('Kategorie',
#               'odswiezacze-powietrza-firmy-sprzatajace'): ['Zurada Aromat Pro'],
#              ('Kategorie', 'odswiezacze-powietrza'): ['Zurada Aromat Pro'],
#              ('Powierzchnie',
#               'powierzchnie wielkometrażowe'): ['Zurada Floor Fresh'],
#              ('BHP', 'unikać wody alkoholu polimeru'): ['Zurada Floor Fresh'],
#              ('Powierzchnie',
#               'powierzchnie obiektowe'): ['Zurada Alkali Floor'],
#              ('Odradzane', 'błony śluzowe'): ['Zurada Czyste Dłonie'],
#              ('Odradzane', 'otwarte rany'): ['Zurada Czyste Dłonie'],
#              ('Metody', 'wcieranie w dłonie'): ['Zurada Czyste Dłonie'],
#              ('Certyfikaty', 'PN-EN 1500-2013'): ['Zurada Czyste Dłonie'],
#              ('Certyfikaty',
#               'przebadany dermatologicznie'): ['Zurada Czyste Dłonie',
#               'Zurada Mydło Dłoni'],
#              ('BHP', 'unikać ran i śluzówek'): ['Zurada Czyste Dłonie'],
#              ('BHP', 'spłukać ręce'): ['Zurada Czyste Dłonie'],
#              ('BHP',
#               'karta i zasady bezpieczeństwa'): ['Zurada Czyste Dłonie'],
#              ('BHP',
#               'dezynfekcja rąk według producenta'): ['Zurada Czyste Dłonie'],
#              ('Powierzchnie', 'posadzki twarde'): ['Zurada Kwas Moc'],
#              ('Powierzchnie', 'płytki'): ['Zurada Kwas Moc',
#               'Zurada Moc Czystości'],
#              ('Powierzchnie', 'powierzchnie mineralne'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'marmur'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'trawertyn'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'beton'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'bazalt'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'łupki'): ['Zurada Kwas Moc'],
#              ('Odradzane', 'granit'): ['Zurada Kwas Moc'],
#              ('Powierzchnie', 'ksylolit'): ['Zurada Strip Moc'],
#              ('Odradzane', 'linoleum'): ['Zurada Strip Moc'],
#              ('Odradzane', 'parkiet'): ['Zurada Strip Moc'],
#              ('Odradzane', 'korek'): ['Zurada Strip Moc'],
#              ('BHP', 'spłukać i osuszyć'): ['Zurada Strip Moc'],
#              ('BHP', 'oczyścić uszczelki'): ['Zurada PiecMax'],
#              ('Powierzchnie', 'odporne na kwasy'): ['Zurada Kwasowa Moc',
#               'Zurada Odkamień Piana',
#               'Zurada Odkamień Proszek'],
#              ('BHP', 'aplikować na ciepło'): ['Zurada Kwasowa Moc'],
#              ('Powierzchnie', 'talerze'): ['Zurada Cytrusowy Blask'],
#              ('BHP', 'recykling opakowania'): ['Zurada Cytrusowy Blask'],
#              ('Kategorie', 'reczne-mycie-naczyn'): ['Zurada Cytrusowy Blask'],
#              ('BHP', 'użytek zewnętrzny'): ['Zurada Mydło Dłoni'],
#              ('Powierzchnie',
#               'bez kontaktu z żywnością'): ['Zurada Chlor Piana'],
#              ('Powierzchnie', 'powierzchnie pionowe'): ['Zurada Chlor Piana'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na chlor'): ['Zurada Chlor Piana'],
#              ('BHP', 'unikać chloru'): ['Zurada Chlor Piana'],
#              ('Powierzchnie', 'wykładziny'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Powierzchnie', 'dywany'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Powierzchnie', 'tapicerka tekstylna'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Powierzchnie', 'dywaniki'): ['Zurada Tkaninex',
#               'Zurada Tapicer Max'],
#              ('Powierzchnie', 'tapicerka samochodowa'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax',
#               'Zurada Tapicer Max'],
#              ('Powierzchnie', 'meble tapicerowane'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus'],
#              ('Odradzane', 'tapicerka skórzana'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('BHP', 'sprawdzić trwałość kolorów'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Kategorie', 'tapicerka'): ['Zurada Tkaninex',
#               'Zurada PiankoMax',
#               'Zurada Tapicer Max'],
#              ('Kategorie',
#               'mycie-tapicerek-firmy-sprzatajace'): ['Zurada Tkaninex', 'Zurada Tkanin Plus', 'Zurada PiankoMax'],
#              ('Kategorie', 'mycie-tapicerek'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Kategorie', 'mycie-tapicerek-instytucje'): ['Zurada Tkaninex',
#               'Zurada Tkanin Plus',
#               'Zurada PiankoMax'],
#              ('Metody', 'pranie'): ['Zurada Tkanin Plus', 'Zurada PiankoMax'],
#              ('Powierzchnie', 'tapicerka meblowa'): ['Zurada PiankoMax'],
#              ('Powierzchnie',
#               'powierzchnie materiałowe'): ['Zurada PiankoMax'],
#              ('Powierzchnie', 'tkaniny'): ['Zurada PiankoMax'],
#              ('Powierzchnie', 'tekstylia'): ['Zurada PiankoMax'],
#              ('Metody', 'czyszczenie'): ['Zurada PiankoMax'],
#              ('Powierzchnie', 'woski'): ['Zurada Winogronowa Piana'],
#              ('Powierzchnie',
#               'powłoki ochronne'): ['Zurada Winogronowa Piana'],
#              ('BHP',
#               'karta i zalecenia producenta'): ['Zurada Winogronowa Piana'],
#              ('Powierzchnie', 'drewno lakierowane'): ['Zurada Meble Blask'],
#              ('Kategorie',
#               'czyszczenie-i-pielegnacja-mebli-firmy-sprzatajace'): ['Zurada Meble Blask'],
#              ('Kategorie',
#               'czyszczenie-i-pielegnacja-mebli'): ['Zurada Meble Blask'],
#              ('Kategorie',
#               'czyszczenie-i-pielegnacja-mebli-instytucje'): ['Zurada Meble Blask'],
#              ('Powierzchnie', 'odporne na wybielacze'): ['Zurada Biel Moc'],
#              ('Powierzchnie', 'schody'): ['Zurada Biel Moc'],
#              ('Odradzane',
#               'powierzchnie wrażliwe na wybielacze'): ['Zurada Biel Moc'],
#              ('BHP', 'unikać aluminium i wybielania'): ['Zurada Biel Moc'],
#              ('BHP', 'spłukać po 15 minutach'): ['Zurada Biel Moc'],
#              ('Odradzane', 'stal'): ['Zurada Kamień Stop'],
#              ('Odradzane', 'żeliwo'): ['Zurada Kamień Stop',
#               'Zurada Krwawy Blask'],
#              ('Odradzane', 'armatura łazienkowa'): ['Zurada Kamień Stop'],
#              ('BHP', 'stosowanie okresowe'): ['Zurada Kamień Stop'],
#              ('BHP', 'spłukać pod ciśnieniem'): ['Zurada Auto Piana',
#               'Zurada Krwawy Blask'],
#              ('Odradzane', 'rozgrzany lakier'): ['Zurada Truck Piana'],
#              ('BHP', 'unikać rozgrzanego lakieru'): ['Zurada Truck Piana'],
#              ('Metody', 'aplikacja gąbką'): ['Zurada Woskowy Blask',
#               'Zurada Lustrzany Blask'],
#              ('Metody', 'aplikacja rękawicą'): ['Zurada Woskowy Blask'],
#              ('Metody', 'spłukiwanie'): ['Zurada Woskowy Blask'],
#              ('Kategorie',
#               'ochrona-osuszanie-i-nablyszczanie-pojazdow'): ['Zurada Woskowy Blask', 'Zurada Kropla Blasku', 'Zurada Hydro Błysk'],
#              ('Powierzchnie', 'felgi'): ['Zurada Krwawy Blask'],
#              ('Powierzchnie', 'polerowane aluminium'): ['Zurada Krwawy Blask'],
#              ('Odradzane', 'tarcze hamulcowe'): ['Zurada Krwawy Blask'],
#              ('Odradzane', 'bębny'): ['Zurada Krwawy Blask'],
#              ('Odradzane', 'zaciski'): ['Zurada Krwawy Blask'],
#              ('BHP', 'unikać żeliwa'): ['Zurada Krwawy Blask'],
#              ('Kategorie', 'mycie-felg-i-kolpakow'): ['Zurada Krwawy Blask'],
#              ('Powierzchnie', 'opony'): ['Zurada Opona Blask'],
#              ('Powierzchnie', 'stal'): ['Zurada Opona Blask'],
#              ('Metody', 'aplikator'): ['Zurada Opona Blask'],
#              ('Kategorie', 'opony'): ['Zurada Opona Blask'],
#              ('Powierzchnie', 'lampy'): ['Zurada Owad Stop'],
#              ('Kategorie', 'usuwanie-owadow'): ['Zurada Owad Stop'],
#              ('Powierzchnie', 'reflektory'): ['Zurada Szybki Blask'],
#              ('Kategorie', 'szyby'): ['Zurada Szybki Blask'],
#              ('Powierzchnie', 'kokpit'): ['Zurada Pianka'],
#              ('Powierzchnie', 'wnętrze samochodu'): ['Zurada Pianka'],
#              ('Kategorie', 'kokpit-i-elementy-plastikowe'): ['Zurada Pianka'],
#              ('Powierzchnie', 'siedzenia'): ['Zurada Tapicer Max'],
#              ('Odradzane', 'brąz'): ['Zurada Odkamień Piana'],
#              ('Powierzchnie',
#               'urządzenia gastronomiczne'): ['Zurada Gastro Moc', 'Zurada Odkamień Proszek'],
#              ('Powierzchnie', 'czajnik tradycyjny'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'czajnik elektryczny'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'ekspresy do kawy'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'zmywarki'): ['Zurada Gastro Moc',
#               'Zurada Odkamień Proszek'],
#              ('Powierzchnie', 'pralki'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'wyparzarki'): ['Zurada Gastro Moc',
#               'Zurada Odkamień Proszek'],
#              ('Powierzchnie', 'bojlery'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'kotły'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'parowniki'): ['Zurada Gastro Moc'],
#              ('Powierzchnie', 'nagrzewnice'): ['Zurada Gastro Moc'],
#              ('Odradzane', 'powierzchnie ocynkowane'): ['Zurada Gastro Moc'],
#              ('Metody', 'ultradźwiękowe'): ['Zurada Fala Czystości'],
#              ('Certyfikaty', 'biodegradowalny'): ['Zurada Fala Czystości'],
#              ('Kategorie', 'mycie-ultradzwiekowe'): ['Zurada Fala Czystości'],
#              ('Kategorie',
#               'mycie-ultradzwiekowe-chemia-samochodowa'): ['Zurada Fala Czystości'],
#              ('Powierzchnie', 'zlewozmywaki'): ['Zurada Moc Czystości'],
#              ('BHP', 'przechowywać 5–25°C'): ['Zurada Moc Czystości'],
#              ('Odradzane', 'rozgrzana karoseria'): ['Zurada Karoseria Blask'],
#              ('Kategorie',
#               'pielegnacja-i-nablyszczanie-z-zewnatrz'): ['Zurada Karoseria Blask', 'Zurada Lustrzany Blask'],
#              ('Odradzane', 'szyba czołowa'): ['Zurada Kropla Blasku'],
#              ('BHP', 'unikać szyby czołowej'): ['Zurada Kropla Blasku'],
#              ('BHP', 'aplikować na lakier'): ['Zurada Kropla Blasku'],
#              ('Powierzchnie', 'czyste elementy'): ['Zurada Lustrzany Blask'],
#              ('Powierzchnie',
#               'porowate powierzchnie'): ['Zurada Lustrzany Blask']})

# %% [markdown]
# ## Krok 2 — Strony konceptów (Metody, Certyfikaty, pH, Powierzchnie, Odradzane, BHP)

# %%
n_concepts = 0
for col, folder in COL_TO_FOLDER.items():
    vals = set()
    for v in df[col].dropna():
        vals.update(parse_list(v))

    for value in vals:
        if not value:
            continue
        desc     = descriptions.get((value, col), '')
        products = concept_products.get((folder, safe(value)), [])
        prod_links = '\n'.join(
            f'- [[{PROD_FOLDER}/{safe(p)}|{p}]]' for p in sorted(products)
        )
        content = (
            f'---\n'
            f'typ: {folder.lower()}\n'
            f'kolumna: {col}\n'
            f'liczba_produktow: {len(products)}\n'
            f'---\n\n'
            f'# {value}\n\n'
            f'{desc if desc else "_Brak opisu._"}\n\n'
            f'## Produkty ({len(products)})\n\n'
            f'{prod_links if prod_links else "_Brak powiązanych produktów._"}\n'
        )
        write_md(VAULT_DIR / folder / f'{safe(value)}.md', content)
        n_concepts += 1

print(f'Koncepty: {n_concepts} plikow')
# Out:
# Koncepty: 360 plikow

# %% [markdown]
# ## Krok 3 — Strony kategorii

# %%
cats_all = set()
for v in df['categories'].dropna():
    cats_all.update(parse_cats(str(v)))

for cat in cats_all:
    if not cat:
        continue
    products  = concept_products.get((CAT_FOLDER, safe(cat)), [])
    prod_links = '\n'.join(
        f'- [[{PROD_FOLDER}/{safe(p)}|{p}]]' for p in sorted(products)
    )
    content = (
        f'---\n'
        f'typ: kategoria\n'
        f'liczba_produktow: {len(products)}\n'
        f'---\n\n'
        f'# {cat}\n\n'
        f'## Produkty ({len(products)})\n\n'
        f'{prod_links if prod_links else "_Brak produktów._"}\n'
    )
    write_md(VAULT_DIR / CAT_FOLDER / f'{safe(cat)}.md', content)

print(f'Kategorie: {len(cats_all)} plikow')
# Out:
# Kategorie: 97 plikow

# %% [markdown]
# ## Krok 4 — Strony produktów

# %%
for _, row in df.iterrows():
    pid   = int(row['product_id'])
    pname = str(row['product_name'])
    title = str(row.get('title', ''))
    short = str(row.get('short_description', ''))
    full  = str(row.get('content_encoded', ''))
    right = str(row.get('right_description', ''))
    ph    = str(row.get('odczyn_ph', '')).strip()

    sections = []

    if ph and ph not in ('nan', ''):
        sections.append(f'**pH:** {wikilink("pH", ph)}')

    for col in ['metoda_mycia', 'zgodnosc_i_certyfikaty']:
        vals = parse_list(row.get(col))
        if vals:
            joined = ' · '.join(wikilink(COL_TO_FOLDER[col], v) for v in vals)
            sections.append(f'**{COL_LABEL[col]}:** {joined}')

    doz = parse_list(row.get('dozwolone_powierzchnie'))
    if doz:
        joined = ' · '.join(wikilink('Powierzchnie', v) for v in doz)
        sections.append(f'**{COL_LABEL["dozwolone_powierzchnie"]}:** {joined}')

    odr = parse_list(row.get('odradzane_powierzchnie'))
    if odr:
        joined = ' · '.join(wikilink('Odradzane', v) for v in odr)
        sections.append(f'**{COL_LABEL["odradzane_powierzchnie"]}:** \u26d4 {joined}')

    bhp = parse_list(row.get('ostrzezenia_bhp'))
    if bhp:
        items = '\n'.join(f'- {wikilink("BHP", v)}' for v in bhp)
        sections.append(f'**{COL_LABEL["ostrzezenia_bhp"]}:**\n{items}')

    cats = parse_cats(str(row.get('categories', '')))
    if cats:
        joined = ' · '.join(wikilink(CAT_FOLDER, c) for c in cats)
        sections.append(f'**Kategorie:** {joined}')

    meta_block = '\n\n'.join(sections)

    yaml_cats   = json.dumps(cats, ensure_ascii=False)
    yaml_metody = json.dumps(parse_list(row.get('metoda_mycia')), ensure_ascii=False)
    yaml_certs  = json.dumps(parse_list(row.get('zgodnosc_i_certyfikaty')), ensure_ascii=False)

    def clean(s):
        return s if s not in ('nan', '') else ''

    content = (
        f'---\n'
        f'product_id: {pid}\n'
        f'title: "{clean(title)}"\n'
        f'ph: "{ph if ph != "nan" else ""}"\n'
        f'metody: {yaml_metody}\n'
        f'certyfikaty: {yaml_certs}\n'
        f'kategorie: {yaml_cats}\n'
        f'---\n\n'
        f'# {pname}\n\n'
        f'> {clean(short)}\n\n'
        f'---\n\n'
        f'{meta_block}\n\n'
        f'---\n\n'
        f'## Opis\n\n{clean(full)}\n\n'
        f'## Właściwości\n\n{clean(right)}\n'
    )
    write_md(VAULT_DIR / PROD_FOLDER / f'{safe(pname)}.md', content)

print(f'Produkty: {len(df)} plikow')
# Out:
# Produkty: 100 plikow

# %% [markdown]
# ## Krok 5 — Strona główna _Index.md

# %%
folder_counts = {}
for folder in [PROD_FOLDER, CAT_FOLDER] + list(COL_TO_FOLDER.values()):
    folder_counts[folder] = len(list((VAULT_DIR / folder).glob('*.md')))

product_list = '\n'.join(
    f'- [[{PROD_FOLDER}/{safe(row["product_name"])}|{row["product_name"]}]]'
    for _, row in df.iterrows()
)

index = (
    '# Katalog Zurada — Mapa Wiedzy\n\n'
    '## Nawigacja\n\n'
    '| Folder | Pliki | Opis |\n'
    '|--------|------:|------|\n'
    f'| [[{PROD_FOLDER}]] | {folder_counts[PROD_FOLDER]} | Produkty czyszczące |\n'
    f'| [[{CAT_FOLDER}]] | {folder_counts[CAT_FOLDER]} | Kategorie sklepowe |\n'
    f'| [[Metody]] | {folder_counts["Metody"]} | Metody mycia |\n'
    f'| [[Certyfikaty]] | {folder_counts["Certyfikaty"]} | Certyfikaty i normy |\n'
    f'| [[pH]] | {folder_counts["pH"]} | Odczyn pH |\n'
    f'| [[Powierzchnie]] | {folder_counts["Powierzchnie"]} | Dozwolone powierzchnie |\n'
    f'| [[Odradzane]] | {folder_counts["Odradzane"]} | Odradzane powierzchnie |\n'
    f'| [[BHP]] | {folder_counts["BHP"]} | Ostrzeżenia BHP |\n\n'
    '## Wszystkie produkty\n\n'
    + product_list + '\n'
)
write_md(VAULT_DIR / '_Index.md', index)

total = sum(1 for _ in VAULT_DIR.rglob('*.md'))
print(f'Vault gotowy: {VAULT_DIR.resolve()}')
print(f'Lacznie {total} plikow .md:')
for folder, count in folder_counts.items():
    print(f'  {folder + "/":20s} {count} plikow')
# Out:
# Vault gotowy: /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/lessons/2_prepare_knowledge_map/zurada_vault
# Lacznie 558 plikow .md:
#   Produkty/            100 plikow
#   Kategorie/           97 plikow
#   Powierzchnie/        201 plikow
#   Odradzane/           48 plikow
#   Metody/              23 plikow
#   Certyfikaty/         20 plikow
#   pH/                  5 plikow
#   BHP/                 63 plikow
