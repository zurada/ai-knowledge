# %% [markdown]
# # Vault RAG — Knowledge Graph Retrieval
#
# ## Problem with naive RAG
#
# The naive approach dumps the **entire product CSV** into the LLM context for every question:
#
# ```
# 262 products × full descriptions → ~70,000 tokens per question
# ```
#
# ## This approach: vault as a knowledge graph + course pattern
#
# Based on lessons 3.3 and 4.1, we follow the two-step retrieval pattern:
#
# ```
# Step 1: LLM reads ONLY a short index (surface/category names)
#         → returns relevant page names as a pydantic model
# Step 2: Load only those vault pages
#         → LLM recommends from focused context (~2–5k tokens)
# ```
#
# **Key tools (from course):**
# - `instructor.patch(client)` — structured output via pydantic, no manual `json.loads`
# - `response_model=MyModel` — LLM returns a validated pydantic object directly
# - `MAP_KNOWLEDGE` — text block embedded in system prompt describing vault rules/structure
#
# **Token savings:**
# ```
# ~70,000 tokens (naive)  →  ~2,000–5,000 tokens (vault RAG)
# ```

# %%
# %pip install instructor
# Out:
# Requirement already satisfied: instructor in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (1.15.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (3.13.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (3.1.6)
# Requirement already satisfied: jiter<0.14,>=0.6.1 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (0.13.0)
# Requirement already satisfied: openai<3.0.0,>=2.0.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (2.37.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (2.46.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (2.34.2)
# Requirement already satisfied: rich<15.0.0,>=13.7.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (14.3.4)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (9.1.4)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from instructor) (0.25.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor) (1.24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from jinja2<4.0.0,>=3.1.4->instructor) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (0.28.1)
# Requirement already satisfied: sniffio in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from openai<3.0.0,>=2.0.0->instructor) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.0.0->instructor) (3.15)
# Requirement already satisfied: certifi in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.8.0->instructor) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.8.0->instructor) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.3->instructor) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.3->instructor) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from rich<15.0.0,>=13.7.0->instructor) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from rich<15.0.0,>=13.7.0->instructor) (2.20.0)
# Requirement already satisfied: click>=8.2.1 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from typer<1.0.0,>=0.9.0->instructor) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from typer<1.0.0,>=0.9.0->instructor) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from typer<1.0.0,>=0.9.0->instructor) (0.0.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/adamzurada/projects/ai-knowledge/rag-product-recommend/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import time
import json
from pathlib import Path
from datetime import datetime
from typing import List

from openai import OpenAI
from pydantic import BaseModel, Field, conlist
import instructor

OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY", "Brak klucza")
#MODEL    = "openai/gpt-5.4-mini"  
#MODEL    = "google/gemma-4-31b-it"
MODEL = "google/gemini-3.1-flash-lite"
BASE_URL = "https://openrouter.ai/api/v1"

BASE_DIR       = Path(".")
VAULT_DIR      = BASE_DIR / "zurada_vault"
QUESTIONS_FILE = BASE_DIR / "../5_navie_rag_extended_data/extended_golden_questions.json"

# instructor.patch → structured output via pydantic, no manual json.loads (lesson 3.3)
_raw_client = OpenAI(api_key=OPENROUTER_API_KEY, base_url=BASE_URL)
client = instructor.patch(_raw_client, mode=instructor.Mode.MD_JSON)

with open(QUESTIONS_FILE, encoding="utf-8") as f:
    questions = json.load(f)

print(f"Model: {MODEL}")
print(f"Vault: {VAULT_DIR}")
print(f"Questions: {len(questions)}")
print(f"API key: {'OK' if OPENROUTER_API_KEY != 'Brak klucza' else 'BRAK'}")
# Out:
# Model: google/gemini-3.1-flash-lite
# Vault: zurada_vault
# Questions: 9
# API key: OK

# %% [markdown]
# ---
# ## MAP_KNOWLEDGE + Pydantic models
#
# **Course pattern (lesson 3.4):** the `Field(description=...)` IS the prompt for each field.
# Instead of injecting 300+ names as a flat list into the prompt body, we put **semantic descriptions with examples** directly in the field definition. Instructor passes these to the model as part of the JSON schema.
#
# Three techniques applied:
# - `MethodEnum` — closed set of 22 valid method names; pydantic rejects anything outside it and instructor retries
# - Rich `Field(description=...)` — top-12 surfaces/categories with semantic hints, so "toaleta" maps to "toalety"
# - Explicit defaults — `"Domyślnie zwróć pustą listę"` prevents the model from guessing when uncertain

# %%
MAP_KNOWLEDGE = """
Vault Zurada to baza wiedzy produktów czyszczących, zorganizowana jako mapa połączonych stron.

Struktura vaultu:
- Powierzchnie/  — strony dla każdej powierzchni (np. toalety, podłogi, szkło)
- Kategorie/     — strony dla każdej kategorii (np. wc, zele-do-wc, odkamienianie)
- Metody/        — metody mycia (np. ręczne, myjnia, pianowanie)
- Produkty/      — pełne opisy produktów (frontmatter: product_id, ph, metody, kategorie)

Zasady odpowiedzi:
- Odpowiadaj WYŁĄCZNIE na podstawie dostarczonych stron produktów
- Nie wymyślaj cech produktów spoza dostarczonych danych
- Odróżniaj formy (żel vs piana), przeznaczenie (domowe vs przemysłowe), metodę (ręczne vs maszynowe)
"""


class ProductCandidate(BaseModel):
    product_id: int
    reason: str = Field(description="Jedno zdanie uzasadnienia")


class RecommendModel(BaseModel):
    chain_of_thought: List[str]         = Field(default_factory=list)
    product_ids: List[ProductCandidate] = Field(default_factory=list)


print("MAP_KNOWLEDGE and RecommendModel defined")
print("IntentModel will be defined after vault index is loaded")
# Out:
# MAP_KNOWLEDGE and RecommendModel defined
# IntentModel will be defined after vault index is loaded

# %% [markdown]
# ---
# ## Step 0 — Build vault index
#
# Parse the vault once at startup: build maps of `surface/category → product names`.
# No LLM needed here — pure file parsing.

# %%
def parse_product_links(md_text: str) -> list[str]:
    return re.findall(r'\[\[Produkty/([^|\]]+)[|\]]', md_text)


def parse_frontmatter_field(md_text: str, field: str):
    m = re.search(rf'^{field}:\s*(.+)$', md_text, re.MULTILINE)
    return m.group(1).strip() if m else None


name_to_id: dict[str, int] = {}
for f in (VAULT_DIR / "Produkty").glob("*.md"):
    text = f.read_text(encoding="utf-8")
    pid  = parse_frontmatter_field(text, "product_id")
    if pid:
        name_to_id[f.stem] = int(pid)

surfaces_index: dict[str, list[str]] = {}
for f in (VAULT_DIR / "Powierzchnie").glob("*.md"):
    surfaces_index[f.stem] = parse_product_links(f.read_text(encoding="utf-8"))

categories_index: dict[str, list[str]] = {}
for f in (VAULT_DIR / "Kategorie").glob("*.md"):
    categories_index[f.stem] = parse_product_links(f.read_text(encoding="utf-8"))

methods_index: dict[str, list[str]] = {}
for f in (VAULT_DIR / "Metody").glob("*.md"):
    methods_index[f.stem] = parse_product_links(f.read_text(encoding="utf-8"))

print(f"Products: {len(name_to_id)}  Surfaces: {len(surfaces_index)}  "
      f"Categories: {len(categories_index)}  Methods: {len(methods_index)}")
# Out:
# Products: 262  Surfaces: 307  Categories: 285  Methods: 22

# %%
import enum as _enum

# --- helpers ---

def _page_description(path: Path) -> str:
    text  = path.read_text(encoding="utf-8")
    parts = text.split("---", 2)
    body  = parts[2] if len(parts) >= 3 else text
    for line in body.strip().split("\n"):
        line = line.strip()
        if line and not line.startswith("#") and not line.startswith("-"):
            return line[:100]
    return ""


def _make_enum(name: str, keys: list[str]) -> type:
    """Build a str-enum from vault page names.
    Pydantic validates returned values against the enum;
    instructor retries automatically when the model returns an invalid name.
    """
    return _enum.Enum(
        name,
        {k.upper().replace(" ", "_").replace("-", "_").replace("(", "").replace(")", ""): k
         for k in sorted(keys)},
        type=str,
    )


# --- Three closed-set enums (lesson 3.4 pattern) ---
# Pro: exact-match validation + automatic retry on invalid values
# Cost: instructor embeds the full enum schema in the prompt
#   MethodEnum   22 values  →  negligible token cost
#   SurfaceEnum  307 values →  ~1,500 extra tokens per call
#   CategoryEnum 285 values →  ~1,400 extra tokens per call

MethodEnum   = _make_enum("MethodEnum",   list(methods_index.keys()))
SurfaceEnum  = _make_enum("SurfaceEnum",  list(surfaces_index.keys()))
CategoryEnum = _make_enum("CategoryEnum", list(categories_index.keys()))

_method_desc = "; ".join(
    f"{m.value}: {_page_description(VAULT_DIR / 'Metody' / f'{m.value}.md')}"
    for m in MethodEnum
)


# --- IntentModel with all three enums ---
class IntentModel(BaseModel):
    surfaces: List[SurfaceEnum] = Field(
        default_factory=list,
        description=(
            "Powierzchnie fizyczne wymienione lub sugerowane w pytaniu. "
            "Domyślnie zwróć pustą listę jeśli brak jednoznacznego dopasowania."
        ),
    )
    categories: List[CategoryEnum] = Field(
        default_factory=list,
        description=(
            "Kategorie produktów pasujące do pytania. "
            "Domyślnie zwróć pustą listę jeśli brak jednoznacznego dopasowania."
        ),
    )
    methods: List[MethodEnum] = Field(
        default_factory=list,
        description=(
            "Metody aplikacji wymagane w pytaniu. "
            "Wybierz tylko jeśli pytanie jawnie wskazuje metodę. "
            "Domyślnie zwróć pustą listę. "
            f"Dostępne: {_method_desc}"
        ),
    )
    reasoning_steps: List[str] = Field(default_factory=list)


print(f"SurfaceEnum:  {len(list(SurfaceEnum))} values")
print(f"CategoryEnum: {len(list(CategoryEnum))} values")
print(f"MethodEnum:   {len(list(MethodEnum))} values")
print("All three use closed-set validation → instructor retries on invalid names")
# Out:
# SurfaceEnum:  307 values
# CategoryEnum: 285 values
# MethodEnum:   22 values
# All three use closed-set validation → instructor retries on invalid names

# %% [markdown]
# ---
# ## Step 1 — Extract intent from the question
#
# A small, cheap LLM call that asks: *what surfaces, categories and methods does this question relate to?*
# The LLM returns keys that map directly to vault page names.

# %%
# Simplified prompt — Field descriptions carry the full semantic context
INTENT_SYSTEM = """Jesteś asystentem pomagającym znaleźć odpowiednie produkty czyszczące Zurada.

{MAP_KNOWLEDGE}

Na podstawie pytania klienta zidentyfikuj, które strony vaultu są potrzebne.
Wybierz tylko te, które są ściśle związane z pytaniem. Nie wybieraj więcej niż 5 pozycji łącznie."""


INTENT_SYSTEM_2 = """Jesteś analitykiem zapytań dla bazy wiedzy produktów czyszczących Zurada.

{MAP_KNOWLEDGE}

Na podstawie pytania klienta zidentyfikuj, które strony vaultu (powierzchnie, kategorie, metody) są potrzebne.
ZASADA: Bądź hojny. Jeśli użytkownik pyta o "aluminiowe części maszyn i narzędzia warsztatowe", zaznacz wszystkie powiązane kategorie (np. aluminium, metal, warsztat, odtłuszczanie).
Wybierz od 1 do maksymalnie 6 najbardziej pasujących pozycji."""

INTENT_SYSTEM_3 = """Jesteś analitykiem zapytań dla bazy wiedzy produktów czyszczących Zurada.

{MAP_KNOWLEDGE}

Na podstawie pytania klienta zidentyfikuj, które strony vaultu są potrzebne.
ZASADY KRYTYCZNE:
1. UŻYWAJ WYŁĄCZNIE WARTOŚCI Z LISTY. Nie wymyślaj własnych słów (np. nie używaj słowa "muszla", jeśli nie ma go w dostępnym Enumie).
2. ZACHOWAJ ORYGINALNĄ PISOWNIĘ Z ENUMÓW. Jeśli kategoria w schemacie nie ma polskich znaków (np. "reczne-mycie-naczyn"), zwróć ją DOKŁADNIE w takiej formie, bez "ę", "ń" itp.
3. KATEGORYZUJ POPRAWNIE: 
   - 'surfaces' to fizyczne obiekty (np. 'toalety', 'blaty'). Nigdy nie wkładaj tu procesów ani typów chemii.
   - 'categories' to grupy chemii domowej/warsztatowej.
Wybierz od 1 do maksymalnie 6 najbardziej pasujących pozycji per pole."""

def extract_intent(question: str) -> IntentModel:
    intent: IntentModel = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": INTENT_SYSTEM_3.format(MAP_KNOWLEDGE=MAP_KNOWLEDGE)},
            {"role": "user",   "content": question},
        ],
        response_model=IntentModel,
        max_tokens=4000,
        temperature=0,
    )
    return intent


demo_q = questions[0]
intent = extract_intent(demo_q["question"])
print(f"Question:   {demo_q['question']}")
print(f"Surfaces:   {intent.surfaces}")
print(f"Categories: {intent.categories}")
print(f"Methods:    {[m.value for m in intent.methods]}")
print(f"Reasoning:  {intent.reasoning_steps}")
# Out:
# Question:   Potrzebuję zwykłego, gęstego żelu do codziennego mycia toalety w domu, żeby usunąć trochę kamienia i odświeżyć muszlę.
# Surfaces:   [<SurfaceEnum.TOALETY: 'toalety'>]
# Categories: [<CategoryEnum.WC: 'wc'>, <CategoryEnum.ZELE_DO_WC: 'zele-do-wc'>, <CategoryEnum.ODKAMIENIANIE: 'odkamienianie'>, <CategoryEnum.DLA_DOMU: 'dla-domu'>]
# Methods:    ['ręczne']
# Reasoning:  ['Klient poszukuje produktu do codziennego mycia toalety w domu.', "Wymagana forma to 'gęsty żel', co wskazuje na kategorię 'zele-do-wc'.", "Produkt musi usuwać kamień, więc uwzględniono kategorię 'odkamienianie'.", "Zastosowanie domowe kwalifikuje zapytanie do kategorii 'dla-domu'.", 'Metoda aplikacji w przypadku żelu do WC jest ręczna (bezpośrednie naniesienie z butelki).']

# %% [markdown]
# ---
# ## Step 2 — Look up vault pages
#
# Use the intent to find candidate products.
# No LLM — pure index lookup using the vault's linked structure.

# %%
def lookup_candidates(intent: IntentModel) -> set[str]:
    """Step 2: pure Python vault lookup — all enum values use .value to get the string key."""
    candidates: set[str] = set()

    for surface in intent.surfaces:
        candidates.update(surfaces_index.get(surface.value, []))

    for cat in intent.categories:
        candidates.update(categories_index.get(cat.value, []))

    for method in intent.methods:
        if not candidates:  # methods are broad — only use as fallback
            candidates.update(methods_index.get(method.value, []))

    return candidates


candidates = lookup_candidates(intent)
print(f"Candidate products ({len(candidates)}): ")
candidates_id = [name_to_id[c] for c in candidates if c in name_to_id]
for c in sorted(candidates_id):
    print(f"- {c}")
# Out:
# Candidate products (48):
# - 10
# - 11
# - 12
# - 25
# - 29
# - 51
# - 79
# - 80
# - 82
# - 92
# - 93
# - 127
# - 128
# - 129
# - 130
# - 131
# - 133
# - 134
# - 135
# - 136
# - 137
# - 139
# - 211
# - 212
# - 213
# - 214
# - 215
# - 216
# - 217
# - 218
# - 219
# - 220
# - 221
# - 222
# - 223
# - 224
# - 225
# - 226
# - 227
# - 228
# - 230
# - 231
# - 234
# - 235
# - 236
# - 238
# - 239
# - 240

# %% [markdown]
# ---
# ## Step 3 — Read candidate product pages
#
# Load only the `.md` files for the candidate products from the vault.
# Each page contains the full product description, pH, surfaces, safety notes — everything the LLM needs.

# %%
def load_product_pages(product_names: set[str]) -> str:
    """Read vault pages for the given product names and return them as one text block."""
    pages = []
    for name in sorted(product_names):
        path = VAULT_DIR / "Produkty" / f"{name}.md"
        if path.exists():
            pages.append(path.read_text(encoding="utf-8"))
    return "\n\n---\n\n".join(pages)


product_context = load_product_pages(candidates)
chars  = len(product_context)
approx = chars // 4
print(f"Loaded {len(candidates)} product pages")
print(f"Context size: {chars:,} chars (~{approx:,} tokens)")
print(f"Naive CSV was: ~70,000 tokens → saving ~{70000 - approx:,} tokens ({(70000-approx)/70000*100:.0f}%)")
# Out:
# Loaded 48 product pages
# Context size: 81,298 chars (~20,324 tokens)
# Naive CSV was: ~70,000 tokens → saving ~49,676 tokens (71%)

# %% [markdown]
# ---
# ## Step 4 — Ask LLM with only the relevant products
#
# The LLM now sees a focused, small context instead of the entire catalog.

# %%
RECOMMEND_SYSTEM = """Jesteś ekspertem ds. środków czystości firmy Zurada.

{MAP_KNOWLEDGE}

Poniżej otrzymasz wybrane strony produktów z bazy wiedzy Zurada w formacie Markdown.
Na podstawie tych stron odpowiedz na pytanie klienta — wskaż pasujące produkty z ich product_id."""

RECOMMEND_SYSTEM_2 = """Jesteś rygorystycznym ekspertem ds. środków czystości firmy Zurada.

{MAP_KNOWLEDGE}

Poniżej otrzymasz wybrane strony produktów z bazy wiedzy Zurada w formacie Markdown.
Twoim zadaniem jest trafna odpowiedź na pytanie klienta, wybierając odpowiednie produkty TYLKO z dostarczonego kontekstu.

Zasady analizy (Logika i Bezpieczeństwo):
1. Opieraj się w 100% na faktach z dostarczonych stron. Nie wymyślaj przeznaczenia produktu.
2. Zwracaj uwagę na wykluczenia ('odradzane_powierzchnie'). Używaj logiki chemicznej (np. marmur to wrażliwy kamień naturalny, unikaj kwasów). Jeśli dany środek jest wyraźnie niebezpieczny dla klienta - pomiń go.
3. Czytaj intencję klienta: odróżniaj środki do mycia ręcznego od maszynowego (zmywarki) oraz formy aplikacji (żel vs piana).
4. Dopasuj kontekst i skalę zastosowania: Odróżniaj codzienne zastosowania domowe od specjalistycznej chemii przemysłowej, warsztatowej lub gastronomicznej (HoReCa).
5. Jeśli dany środek ogólnie pasuje do czyszczonej powierzchni i nie ma wyraźnych przeciwwskazań, możesz go polecić.

Jeśli żaden produkt nie pasuje lub użycie każdego grozi zniszczeniem powierzchni — zwróć pustą listę product_ids."""

def recommend(question: str, product_context: str) -> RecommendModel:
    """Step 4: focused LLM call → returns RecommendModel (instructor validates types)."""
    system = RECOMMEND_SYSTEM_2.format(MAP_KNOWLEDGE=MAP_KNOWLEDGE)
    user_msg = f"Strony produktów:\n\n{product_context}\n\n---\n\nPytanie klienta: {question}"

    # response_model=RecommendModel → instructor returns validated RecommendModel directly
    result: RecommendModel = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system},
            {"role": "user",   "content": user_msg},
        ],
        response_model=RecommendModel,
        max_tokens=4000,
        temperature=0,
    )
    return result


result = recommend(demo_q["question"], load_product_pages(candidates))

returned_ids = [c.product_id for c in result.product_ids]
print(f"Question:  {demo_q['question']}")
print(f"Expected:  {demo_q['expectedProductIds']}")
print(f"Candidates: {sorted(candidates_id)}")
print(f"Returned:  {returned_ids}")
print(f"Reasoning: {result.chain_of_thought}")
for c in result.product_ids:
    print(f"  [{c.product_id}] {c.reason}")
# Out:
# Question:  Potrzebuję zwykłego, gęstego żelu do codziennego mycia toalety w domu, żeby usunąć trochę kamienia i odświeżyć muszlę.
# Expected:  [12, 82, 139]
# Candidates: [10, 11, 12, 25, 29, 51, 79, 80, 82, 92, 93, 127, 128, 129, 130, 131, 133, 134, 135, 136, 137, 139, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 230, 231, 234, 235, 236, 238, 239, 240]
# Returned:  [139]
# Reasoning: ['Klient poszukuje gęstego żelu do codziennego mycia toalety w domu.', 'Produkt musi usuwać kamień i odświeżać muszlę.', "Przeglądam bazę produktów pod kątem kategorii 'wc' lub 'zele-do-wc' oraz przeznaczenia domowego.", 'Produkt 139 (Zurada WC Żel Dom) jest gęstym żelem do czyszczenia toalet, usuwa kamień i rdzę, jest przeznaczony do użytku domowego.', 'Produkt 82 (Zurada Toaleta Żel) jest ekologicznym żelem do toalet, ale opisuje go jako skoncentrowany, a niekoniecznie gęsty (choć skuteczny).', 'Produkt 79 (Zurada Biel Moc) jest gęstym żelem, ale jest to środek wybielający (chlorowy), co może być zbyt agresywne dla codziennego mycia, jeśli klient nie prosił o wybielanie.', "Produkt 139 jest najbardziej precyzyjną odpowiedzią na zapotrzebowanie klienta na 'zwykły, gęsty żel do codziennego mycia'.", 'Produkt 80 (Zurada Kamień Gastro) jest przeznaczony do zastosowań profesjonalnych (Horeca/firmy sprzątające) i okresowego usuwania bardzo starego kamienia, więc nie jest optymalny do codziennego mycia w domu.']
#   [139] Jest to gęsty żel przeznaczony do codziennego czyszczenia toalet w domu, który skutecznie usuwa kamień i osady, pozostawiając świeży zapach.

# %% [markdown]
# ---
# ## Full pipeline — run all questions

# %%
def vault_rag_pipeline(question: str) -> tuple[list[int], dict]:
    """Full pipeline: intent → vault lookup → product pages → recommend. Returns (ids, stats)."""
    t0 = time.perf_counter()

    intent: IntentModel = extract_intent(question)
    #time.sleep(0.1)

    candidates      = lookup_candidates(intent)
    product_context = load_product_pages(candidates)

    rec: RecommendModel = recommend(question, product_context)
    #time.sleep(0.1)

    elapsed = time.perf_counter() - t0

    returned_ids = [c.product_id for c in rec.product_ids]
    stats = {
        "intent":       {"surfaces": [s.value for s in intent.surfaces],
                         "categories": [c.value for c in intent.categories],
                         "methods": [m.value for m in intent.methods]},
        "n_candidates": len(candidates),
        "n_tokens_est": len(product_context) // 4,
        "time_seconds": round(elapsed, 2),
    }
    return returned_ids, stats


results = []

for q in questions:
    qid      = q["id"]
    expected = set(q["expectedProductIds"])

    try:
        returned_ids, stats = vault_rag_pipeline(q["question"])
        returned = set(returned_ids)
        error = None
    except Exception as e:
        returned, stats, error = set(), {"n_candidates": 0, "intent": {}, "time_seconds": 0}, str(e)

    hit     = expected & returned
    missed  = expected - returned
    extra   = returned - expected
    correct = returned == expected

    results.append({
        "id":           qid,
        "difficulty":   q.get("difficulty", ""),
        "expected":     sorted(expected),
        "returned":     sorted(returned),
        "hit":          sorted(hit),
        "missed":       sorted(missed),
        "extra":        sorted(extra),
        "correct":      correct,
        "n_candidates": stats.get("n_candidates", 0),
        "n_tokens_est": stats.get("n_tokens_est", 0),
        "time_seconds": stats.get("time_seconds", 0),
        "intent":       stats.get("intent", {}),
        "error":        error,
    })

    status = "✓" if correct else "✗"
    print(f"[{status}] Q{qid:02d} [{q['difficulty']:4s}] "
          f"candidates={stats.get('n_candidates',0):3d}  "
          f"~tokens={stats.get('n_tokens_est',0):5,}  "
          f"time={stats.get('time_seconds',0):.1f}s  "
          f"expected={sorted(expected)}  returned={sorted(returned)}")

correct_total = sum(r["correct"] for r in results)
print(f"\n{correct_total}/{len(results)} exact matches  "
      f"avg time={sum(r['time_seconds'] for r in results)/len(results):.1f}s")
# Out:
# [✗] Q01 [easy] candidates= 48  ~tokens=20,324  time=3.2s  expected=[12, 82, 139]  returned=[82, 139]
# [✓] Q08 [easy] candidates= 24  ~tokens=8,761  time=3.8s  expected=[136, 137, 189, 190]  returned=[136, 137, 189, 190]
# [✓] Q09 [easy] candidates=  8  ~tokens=3,281  time=3.3s  expected=[233, 257]  returned=[233, 257]
# [✗] Q10 [easy] candidates= 18  ~tokens=6,404  time=2.3s  expected=[213, 217, 218]  returned=[213, 218]
# [✗] Q02 [easy] candidates=  0  ~tokens=    0  time=0.0s  expected=[5, 34, 128]  returned=[]
# [✗] Q03 [hard] candidates= 61  ~tokens=27,088  time=4.3s  expected=[45, 112, 152]  returned=[112, 122, 144]
# [✗] Q04 [hard] candidates= 23  ~tokens=13,541  time=2.7s  expected=[11]  returned=[]
# [✗] Q05 [easy] candidates= 70  ~tokens=30,696  time=5.2s  expected=[2, 39, 41, 129]  returned=[129]
# [✗] Q06 [easy] candidates= 50  ~tokens=21,149  time=2.4s  expected=[7, 69]  returned=[69]
#
# 2/9 exact matches  avg time=3.0s

# %% [markdown]
# ---
# ## Results summary

# %%
import pandas as pd

df = pd.DataFrame(results)

n_correct = df["correct"].sum()
n_total   = len(df)

print("=" * 65)
print(f"RESULT: {n_correct}/{n_total} exact matches ({n_correct/n_total*100:.1f}%)")
print(f"Avg candidates/q:   {df['n_candidates'].mean():>8.1f}  (out of 262 total)")
print(f"Avg ~tokens/q:      {df['n_tokens_est'].mean():>8,.0f}  (naive: ~70,000)")
print("=" * 65)
print()

display_cols = ["id", "difficulty", "expected", "returned", "correct", "missed", "extra", "n_candidates"]
print(df[display_cols].to_string(index=False))
print()

errors = df[~df["correct"]]
if not errors.empty:
    print(f"Wrong answers ({len(errors)}):\n")
    for _, row in errors.iterrows():
        print(f"  Q{row['id']:02d} [{row['difficulty']}]")
        print(f"    expected:   {row['expected']}")
        print(f"    returned:   {row['returned']}")
        print(f"    missed:     {row['missed']}")
        print(f"    extra:      {row['extra']}")
        print(f"    candidates: {row['n_candidates']}  intent: {row['intent']}")
# Out:
# =================================================================
# RESULT: 2/9 exact matches (22.2%)
# Avg candidates/q:       33.6  (out of 262 total)
# Avg ~tokens/q:        14,583  (naive: ~70,000)
# =================================================================
#
#  id difficulty             expected             returned  correct       missed      extra  n_candidates
#   1       easy        [12, 82, 139]            [82, 139]    False         [12]         []            48
#   8       easy [136, 137, 189, 190] [136, 137, 189, 190]     True           []         []            24
#   9       easy           [233, 257]           [233, 257]     True           []         []             8
#  10       easy      [213, 217, 218]           [213, 218]    False        [217]         []            18
#   2       easy         [5, 34, 128]                   []    False [5, 34, 128]         []             0
#   3       hard       [45, 112, 152]      [112, 122, 144]    False    [45, 152] [122, 144]            61
#   4       hard                 [11]                   []    False         [11]         []            23
#   5       easy     [2, 39, 41, 129]                [129]    False  [2, 39, 41]         []            70
#   6       easy              [7, 69]                 [69]    False          [7]         []            50
#
# Wrong answers (7):
#
#   Q01 [easy]
#     expected:   [12, 82, 139]
#     returned:   [82, 139]
#     missed:     [12]
#     extra:      []
#     candidates: 48  intent: {'surfaces': ['toalety'], 'categories': ['wc', 'zele-do-wc', 'odkamienianie', 'dla-domu'], 'methods': ['ręczne']}
#   Q10 [easy]
#     expected:   [213, 217, 218]
#     returned:   [213, 218]
#     missed:     [217]
#     extra:      []
#     candidates: 18  intent: {'surfaces': ['powietrze'], 'categories': ['odswiezacze-powietrza'], 'methods': []}
#   Q02 [easy]
#     expected:   [5, 34, 128]
#     returned:   []
#     missed:     [5, 34, 128]
#     extra:      []
#     candidates: 0  intent: {}
#   Q03 [hard]
#     expected:   [45, 112, 152]
#     returned:   [112, 122, 144]
#     missed:     [45, 152]
#     extra:      [122, 144]
#     candidates: 61  intent: {'surfaces': ['narzędzia warsztatowe', 'części maszyn', 'aluminium', 'części metalowe'], 'categories': ['odtluszczacze', 'czyszczenie-aluminium', 'chemia-warsztatowa', 'mycie-i-odtluszczanie'], 'methods': ['ręczne', 'zanurzeniowe']}
#   Q04 [hard]
#     expected:   [11]
#     returned:   []
#     missed:     [11]
#     extra:      []
#     candidates: 23  intent: {'surfaces': ['marmur', 'umywalki', 'blaty', 'armatura'], 'categories': ['czyszczenie-kamienia', 'odkamienianie', 'plyny-do-lazienki', 'srodki-do-lazienki'], 'methods': ['ręczne']}
#   Q05 [easy]
#     expected:   [2, 39, 41, 129]
#     returned:   [129]
#     missed:     [2, 39, 41]
#     extra:      []
#     candidates: 70  intent: {'surfaces': ['szkło', 'szyby', 'lustra'], 'categories': ['mycie-szyb-i-luster', 'plyny-do-szyb', 'dla-domu'], 'methods': ['ręczne']}
#   Q06 [easy]
#     expected:   [7, 69]
#     returned:   [69]
#     missed:     [7]
#     extra:      []
#     candidates: 50  intent: {'surfaces': ['naczynia', 'sztućce', 'talerze'], 'categories': ['reczne-mycie-naczyn', 'dla-domu', 'chemia-domowa'], 'methods': ['ręczne']}

# %% [markdown]
# ---
# ## Save results for metrics analysis

# %%
N_RUNS      = 8
OUTPUT_FILE = BASE_DIR / "vault_rag_runs.json"

repeated = []

for q in questions:
    qid  = q["id"]
    runs = []

    for run_idx in range(1, N_RUNS + 1):
        try:
            returned_ids, stats = vault_rag_pipeline(q["question"])
            runs.append({
                "run":          run_idx,
                "returned_ids": returned_ids,
                "model":        MODEL,
                "n_candidates": stats["n_candidates"],
                "time_seconds": stats["time_seconds"],
                "intent":       stats["intent"],
            })
        except Exception as e:
            runs.append({"run": run_idx, "error": str(e)})

    times = [r["time_seconds"] for r in runs if "time_seconds" in r]
    avg_time = round(sum(times) / len(times), 2) if times else None

    repeated.append({
        "id":                   qid,
        "question":             q["question"],
        "expectedProductIds":   q["expectedProductIds"],
        "expectedNoProductIds": q["expectedNoProductIds"],
        "difficulty":           q.get("difficulty", ""),
        "avg_time_seconds":     avg_time,
        "runs":                 runs,
    })

    expected_set = set(q["expectedProductIds"])
    n_correct    = sum(1 for r in runs if set(r.get("returned_ids", [])) == expected_set)
    print(f"Q{qid:02d} [{q['difficulty']:4s}] {n_correct}/{N_RUNS} correct  avg={avg_time:.1f}s")

with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump({
        "timestamp": datetime.now().isoformat(),
        "model":     MODEL,
        "approach":  "vault_rag",
        "n_runs":    N_RUNS,
        "questions": repeated,
    }, f, ensure_ascii=False, indent=2)

print(f"\nSaved: {OUTPUT_FILE}")
# Out:
# Q01 [easy] 0/8 correct  avg=3.1s
# Q08 [easy] 8/8 correct  avg=3.7s
# Q09 [easy] 8/8 correct  avg=3.7s
# Q10 [easy] 0/8 correct  avg=2.4s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[178], line 39
#      35     })
#      36
#      37     expected_set = set(q["expectedProductIds"])
#      38     n_correct    = sum(1 for r in runs if set(r.get("returned_ids", [])) == expected_set)
# ---> 39     print(f"Q{qid:02d} [{q['difficulty']:4s}] {n_correct}/{N_RUNS} correct  avg={avg_time:.1f}s")
#      40
#      41 with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
#      42     json.dump({
#
# TypeError: unsupported format string passed to NoneType.__format__
